# %%
from IPython.core.display import display, HTML

import pandas as pd
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import os
import gc

from joblib import Parallel, delayed

from sklearn import preprocessing, model_selection
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt 
import seaborn as sns
import numpy.matlib


path_submissions = '/'

target_name = 'target'
scores_folds = {}

# %%
# data directory
data_dir = '../input/optiver-realized-volatility-prediction/'

# Function to calculate first WAP
def calc_wap1(df):
    wap = (df['bid_price1'] * df['ask_size1'] + df['ask_price1'] * df['bid_size1']) / (df['bid_size1'] + df['ask_size1'])
    return wap

# Function to calculate second WAP
def calc_wap2(df):
    wap = (df['bid_price2'] * df['ask_size2'] + df['ask_price2'] * df['bid_size2']) / (df['bid_size2'] + df['ask_size2'])
    return wap

def calc_wap3(df):
    wap = (df['bid_price1'] * df['bid_size1'] + df['ask_price1'] * df['ask_size1']) / (df['bid_size1'] + df['ask_size1'])
    return wap

def calc_wap4(df):
    wap = (df['bid_price2'] * df['bid_size2'] + df['ask_price2'] * df['ask_size2']) / (df['bid_size2'] + df['ask_size2'])
    return wap

def calc_bollinger_band1(df):
    window=10
    wap_bol_upper = df["wap1"].rolling(window=window).mean() + (df["wap1"].rolling(window=window).std() * 2)
    wap_bol_lower = df["wap1"].rolling(window=window).mean() - (df["wap1"].rolling(window=window).std() * 2)
    wap_bol_balance = wap_bol_upper - wap_bol_lower
    return wap_bol_balance

def calc_bollinger_band2(df):
    window=10
    wap_bol_upper = df["wap2"].rolling(window=window).mean() + (df["wap2"].rolling(window=window).std() * 2)
    wap_bol_lower = df["wap2"].rolling(window=window).mean() - (df["wap2"].rolling(window=window).std() * 2)
    wap_bol_balance = wap_bol_upper - wap_bol_lower
    return wap_bol_balance

def calc_bollinger_band3(df):
    window=10
    wap_bol_upper = df["wap3"].rolling(window=window).mean() + (df["wap3"].rolling(window=window).std() * 2)
    wap_bol_lower = df["wap3"].rolling(window=window).mean() - (df["wap3"].rolling(window=window).std() * 2)
    wap_bol_balance = wap_bol_upper - wap_bol_lower
    return wap_bol_balance

def calc_bollinger_band4(df):
    window=10
    wap_bol_upper = df["wap4"].rolling(window=window).mean() + (df["wap4"].rolling(window=window).std() * 2)
    wap_bol_lower = df["wap4"].rolling(window=window).mean() - (df["wap4"].rolling(window=window).std() * 2)
    wap_bol_balance = wap_bol_upper - wap_bol_lower
    return wap_bol_balance

# Function to calculate the log of the return
# Remember that logb(x / y) = logb(x) - logb(y)
def log_return(series):
    return np.log(series).diff()

# Calculate the realized volatility
def realized_volatility(series):
    return np.sqrt(np.sum(series**2))

# Function to count unique elements of a series
def count_unique(series):
    return len(np.unique(series))

# Function to read our base train and test set
def read_train_test():
    train = pd.read_csv('../input/optiver-realized-volatility-prediction/train.csv')
    test = pd.read_csv('../input/optiver-realized-volatility-prediction/test.csv')
    # Create a key to merge with book and trade data
    train['row_id'] = train['stock_id'].astype(str) + '-' + train['time_id'].astype(str)
    test['row_id'] = test['stock_id'].astype(str) + '-' + test['time_id'].astype(str)
    print(f'Our training set has {train.shape[0]} rows')
    return train, test

# Function to preprocess book data (for each stock id)
def book_preprocessor(file_path):
    df = pd.read_parquet(file_path)
    # Calculate Wap
    df['wap1'] = calc_wap1(df)
    df['wap2'] = calc_wap2(df)
    df['wap3'] = calc_wap3(df)
    df['wap4'] = calc_wap4(df)
    # Calculate log returns
    df['log_return1'] = df.groupby(['time_id'])['wap1'].apply(log_return)
    df['log_return2'] = df.groupby(['time_id'])['wap2'].apply(log_return)
    df['log_return3'] = df.groupby(['time_id'])['wap3'].apply(log_return)
    df['log_return4'] = df.groupby(['time_id'])['wap4'].apply(log_return)
    # Calculate wap balance
    df['wap_balance'] = abs(df['wap1'] - df['wap2'])
    # Calculate spread
    df['price_spread'] = (df['ask_price1'] - df['bid_price1']) / ((df['ask_price1'] + df['bid_price1']) / 2)
    df['price_spread2'] = (df['ask_price2'] - df['bid_price2']) / ((df['ask_price2'] + df['bid_price2']) / 2)
    df['bid_spread'] = df['bid_price1'] - df['bid_price2']
    df['ask_spread'] = df['ask_price1'] - df['ask_price2']
    df["bid_ask_spread"] = abs(df['bid_spread'] - df['ask_spread'])
    df['total_volume'] = (df['ask_size1'] + df['ask_size2']) + (df['bid_size1'] + df['bid_size2'])
    df['volume_imbalance'] = abs((df['ask_size1'] + df['ask_size2']) - (df['bid_size1'] + df['bid_size2']))
    
    df['bollinger_band_balance1'] = calc_bollinger_band1(df)
    df['bollinger_band_balance2'] = calc_bollinger_band2(df)
    df['bollinger_band_balance3'] = calc_bollinger_band3(df)
    df['bollinger_band_balance4'] = calc_bollinger_band4(df)
    
    # Dict for aggregations
    create_feature_dict = {
        'wap1': [np.sum, np.std],
        'wap2': [np.sum, np.std],
        'wap3': [np.sum, np.std],
        'wap4': [np.sum, np.std],
        'log_return1': [realized_volatility],
        'log_return2': [realized_volatility],
        'log_return3': [realized_volatility],
        'log_return4': [realized_volatility],
        'wap_balance': [np.sum, np.max],
        'price_spread':[np.sum, np.max],
        'price_spread2':[np.sum, np.max],
        'bid_spread':[np.sum, np.max],
        'ask_spread':[np.sum, np.max],
        'total_volume':[np.sum, np.max],
        'volume_imbalance':[np.sum, np.max],
        "bid_ask_spread":[np.sum,  np.max],
        'bollinger_band_balance1':[np.sum, np.max]
    }
    create_feature_dict_time = {
        'log_return1': [realized_volatility],
        'log_return2': [realized_volatility],
        'log_return3': [realized_volatility],
        'log_return4': [realized_volatility],
    }
    
    # Function to get group stats for different windows (seconds in bucket)
    def get_stats_window(fe_dict,seconds_in_bucket, add_suffix = False):
        # Group by the window
        df_feature = df[df['seconds_in_bucket'] >= seconds_in_bucket].groupby(['time_id']).agg(fe_dict).reset_index()
        # Rename columns joining suffix
        df_feature.columns = ['_'.join(col) for col in df_feature.columns]
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature = df_feature.add_suffix('_' + str(seconds_in_bucket))
        return df_feature
    
    # Get the stats for different windows
    df_feature = get_stats_window(create_feature_dict,seconds_in_bucket = 0, add_suffix = False)
    df_feature_500 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 500, add_suffix = True)
    df_feature_400 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 400, add_suffix = True)
    df_feature_300 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 300, add_suffix = True)
    df_feature_200 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 200, add_suffix = True)
    df_feature_100 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 100, add_suffix = True)

    # Merge all
    df_feature = df_feature.merge(df_feature_500, how = 'left', left_on = 'time_id_', right_on = 'time_id__500')
    df_feature = df_feature.merge(df_feature_400, how = 'left', left_on = 'time_id_', right_on = 'time_id__400')
    df_feature = df_feature.merge(df_feature_300, how = 'left', left_on = 'time_id_', right_on = 'time_id__300')
    df_feature = df_feature.merge(df_feature_200, how = 'left', left_on = 'time_id_', right_on = 'time_id__200')
    df_feature = df_feature.merge(df_feature_100, how = 'left', left_on = 'time_id_', right_on = 'time_id__100')
    # Drop unnecesary time_ids
    df_feature.drop(['time_id__500','time_id__400', 'time_id__300', 'time_id__200','time_id__100'], axis = 1, inplace = True)
    
    
    # Create row_id so we can merge
    stock_id = file_path.split('=')[1]
    df_feature['row_id'] = df_feature['time_id_'].apply(lambda x: f'{stock_id}-{x}')
    df_feature.drop(['time_id_'], axis = 1, inplace = True)
    return df_feature

# Function to preprocess trade data (for each stock id)
def trade_preprocessor(file_path):
    df = pd.read_parquet(file_path)
    df['log_return'] = df.groupby('time_id')['price'].apply(log_return)
    df['amount']=df['price']*df['size']
    # Dict for aggregations
    create_feature_dict = {
        'log_return':[realized_volatility],
        'seconds_in_bucket':[count_unique],
        'size':[np.sum, np.max, np.min],
        'order_count':[np.sum,np.max],
        'amount':[np.sum,np.max,np.min],
    }
    create_feature_dict_time = {
        'log_return':[realized_volatility],
        'seconds_in_bucket':[count_unique],
        'size':[np.sum],
        'order_count':[np.sum],
    }
    # Function to get group stats for different windows (seconds in bucket)
    def get_stats_window(fe_dict,seconds_in_bucket, add_suffix = False):
        # Group by the window
        df_feature = df[df['seconds_in_bucket'] >= seconds_in_bucket].groupby(['time_id']).agg(fe_dict).reset_index()
        # Rename columns joining suffix
        df_feature.columns = ['_'.join(col) for col in df_feature.columns]
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature = df_feature.add_suffix('_' + str(seconds_in_bucket))
        return df_feature
    

    # Get the stats for different windows
    df_feature = get_stats_window(create_feature_dict,seconds_in_bucket = 0, add_suffix = False)
    df_feature_500 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 500, add_suffix = True)
    df_feature_400 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 400, add_suffix = True)
    df_feature_300 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 300, add_suffix = True)
    df_feature_200 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 200, add_suffix = True)
    df_feature_100 = get_stats_window(create_feature_dict_time,seconds_in_bucket = 100, add_suffix = True)
    
    def tendency(price, vol):    
        df_diff = np.diff(price)
        val = (df_diff/price[1:])*100
        power = np.sum(val*vol[1:])
        return(power)
    
    lis = []
    for n_time_id in df['time_id'].unique():
        df_id = df[df['time_id'] == n_time_id]        
        tendencyV = tendency(df_id['price'].values, df_id['size'].values)      
        f_max = np.sum(df_id['price'].values > np.mean(df_id['price'].values))
        f_min = np.sum(df_id['price'].values < np.mean(df_id['price'].values))
        df_max =  np.sum(np.diff(df_id['price'].values) > 0)
        df_min =  np.sum(np.diff(df_id['price'].values) < 0)
        # new
        abs_diff = np.median(np.abs( df_id['price'].values - np.mean(df_id['price'].values)))        
        energy = np.mean(df_id['price'].values**2)
        iqr_p = np.percentile(df_id['price'].values,75) - np.percentile(df_id['price'].values,25)
        
        # vol vars
        
        abs_diff_v = np.median(np.abs( df_id['size'].values - np.mean(df_id['size'].values)))        
        energy_v = np.sum(df_id['size'].values**2)
        iqr_p_v = np.percentile(df_id['size'].values,75) - np.percentile(df_id['size'].values,25)
        
        lis.append({'time_id':n_time_id,'tendency':tendencyV,'f_max':f_max,'f_min':f_min,'df_max':df_max,'df_min':df_min,
                   'abs_diff':abs_diff,'energy':energy,'iqr_p':iqr_p,'abs_diff_v':abs_diff_v,'energy_v':energy_v,'iqr_p_v':iqr_p_v})
    
    df_lr = pd.DataFrame(lis)
        
   
    df_feature = df_feature.merge(df_lr, how = 'left', left_on = 'time_id_', right_on = 'time_id')
    
    # Merge all
    df_feature = df_feature.merge(df_feature_500, how = 'left', left_on = 'time_id_', right_on = 'time_id__500')
    df_feature = df_feature.merge(df_feature_400, how = 'left', left_on = 'time_id_', right_on = 'time_id__400')
    df_feature = df_feature.merge(df_feature_300, how = 'left', left_on = 'time_id_', right_on = 'time_id__300')
    df_feature = df_feature.merge(df_feature_200, how = 'left', left_on = 'time_id_', right_on = 'time_id__200')
    df_feature = df_feature.merge(df_feature_100, how = 'left', left_on = 'time_id_', right_on = 'time_id__100')
    # Drop unnecesary time_ids
    df_feature.drop(['time_id__500','time_id__400', 'time_id__300', 'time_id__200','time_id','time_id__100'], axis = 1, inplace = True)
    
    
    df_feature = df_feature.add_prefix('trade_')
    stock_id = file_path.split('=')[1]
    df_feature['row_id'] = df_feature['trade_time_id_'].apply(lambda x:f'{stock_id}-{x}')
    df_feature.drop(['trade_time_id_'], axis = 1, inplace = True)
    return df_feature

# Function to get group stats for the stock_id and time_id
def get_time_stock(df):
    vol_cols = ['log_return1_realized_volatility', 'log_return2_realized_volatility', 'log_return1_realized_volatility_400', 'log_return2_realized_volatility_400', 
                'log_return1_realized_volatility_300', 'log_return2_realized_volatility_300', 'log_return1_realized_volatility_200', 'log_return2_realized_volatility_200', 
                'trade_log_return_realized_volatility', 'trade_log_return_realized_volatility_400', 'trade_log_return_realized_volatility_300', 'trade_log_return_realized_volatility_200']


    # Group by the stock id
    df_stock_id = df.groupby(['stock_id'])[vol_cols].agg(['mean', 'std', 'max', 'min', ]).reset_index()
    # Rename columns joining suffix
    df_stock_id.columns = ['_'.join(col) for col in df_stock_id.columns]
    df_stock_id = df_stock_id.add_suffix('_' + 'stock')

    # Group by the stock id
    df_time_id = df.groupby(['time_id'])[vol_cols].agg(['mean', 'std', 'max', 'min', ]).reset_index()
    # Rename columns joining suffix
    df_time_id.columns = ['_'.join(col) for col in df_time_id.columns]
    df_time_id = df_time_id.add_suffix('_' + 'time')
    
    # Merge with original dataframe
    df = df.merge(df_stock_id, how = 'left', left_on = ['stock_id'], right_on = ['stock_id__stock'])
    df = df.merge(df_time_id, how = 'left', left_on = ['time_id'], right_on = ['time_id__time'])
    df.drop(['stock_id__stock', 'time_id__time'], axis = 1, inplace = True)
    return df
    
# Funtion to make preprocessing function in parallel (for each stock id)
def preprocessor(list_stock_ids, is_train = True):
    
    # Parrallel for loop
    def for_joblib(stock_id):
        # Train
        if is_train:
            file_path_book = data_dir + "book_train.parquet/stock_id=" + str(stock_id)
            file_path_trade = data_dir + "trade_train.parquet/stock_id=" + str(stock_id)
        # Test
        else:
            file_path_book = data_dir + "book_test.parquet/stock_id=" + str(stock_id)
            file_path_trade = data_dir + "trade_test.parquet/stock_id=" + str(stock_id)
    
        # Preprocess book and trade data and merge them
        df_tmp = pd.merge(book_preprocessor(file_path_book), trade_preprocessor(file_path_trade), on = 'row_id', how = 'left')
        
        # Return the merge dataframe
        return df_tmp
    
    # Use parallel api to call paralle for loop
    df = Parallel(n_jobs = -1, verbose = 1)(delayed(for_joblib)(stock_id) for stock_id in list_stock_ids)
    # Concatenate all the dataframes that return from Parallel
    df = pd.concat(df, ignore_index = True)
    return df

# Function to calculate the root mean squared percentage error
def rmspe(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))

# Function to early stop with root mean squared percentage error
def feval_rmspe(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'RMSPE', rmspe(y_true, y_pred), False

# %%
# Read train and test
train, test = read_train_test()

# Get unique stock ids 
train_stock_ids = train['stock_id'].unique()
# Preprocess them using Parallel and our single stock id functions
train_ = preprocessor(train_stock_ids, is_train = True)
train = train.merge(train_, on = ['row_id'], how = 'left')

# Get unique stock ids 
test_stock_ids = test['stock_id'].unique()
# Preprocess them using Parallel and our single stock id functions
test_ = preprocessor(test_stock_ids, is_train = False)
test = test.merge(test_, on = ['row_id'], how = 'left')

# Get group stats of time_id and stock_id
train = get_time_stock(train)
test = get_time_stock(test)
# Out:
# Our training set has 428932 rows
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed: 42.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.4s finished

# %%
# replace by order sum (tau)
train['size_tau'] = np.sqrt( 1/ train['trade_seconds_in_bucket_count_unique'] )
test['size_tau'] = np.sqrt( 1/ test['trade_seconds_in_bucket_count_unique'] )
train['size_tau_400'] = np.sqrt( 1/ train['trade_seconds_in_bucket_count_unique_400'] )
test['size_tau_400'] = np.sqrt( 1/ test['trade_seconds_in_bucket_count_unique_400'] )
train['size_tau_300'] = np.sqrt( 1/ train['trade_seconds_in_bucket_count_unique_300'] )
test['size_tau_300'] = np.sqrt( 1/ test['trade_seconds_in_bucket_count_unique_300'] )
train['size_tau_200'] = np.sqrt( 1/ train['trade_seconds_in_bucket_count_unique_200'] )
test['size_tau_200'] = np.sqrt( 1/ test['trade_seconds_in_bucket_count_unique_200'] )
train['size_tau2'] = np.sqrt( 1/ train['trade_order_count_sum'] )
test['size_tau2'] = np.sqrt( 1/ test['trade_order_count_sum'] )
train['size_tau2_400'] = np.sqrt( 0.33/ train['trade_order_count_sum'] )
test['size_tau2_400'] = np.sqrt( 0.33/ test['trade_order_count_sum'] )
train['size_tau2_300'] = np.sqrt( 0.5/ train['trade_order_count_sum'] )
test['size_tau2_300'] = np.sqrt( 0.5/ test['trade_order_count_sum'] )
train['size_tau2_200'] = np.sqrt( 0.66/ train['trade_order_count_sum'] )
test['size_tau2_200'] = np.sqrt( 0.66/ test['trade_order_count_sum'] )

# delta tau
train['size_tau2_d'] = train['size_tau2_400'] - train['size_tau2']
test['size_tau2_d'] = test['size_tau2_400'] - test['size_tau2']

# %%
colNames = [col for col in list(train.columns)
            if col not in {"stock_id", "time_id", "target", "row_id"}]
len(colNames)
# Out:
# 196

# %%
from sklearn.cluster import KMeans
# making agg features

train_p = pd.read_csv('../input/optiver-realized-volatility-prediction/train.csv')
train_p = train_p.pivot(index='time_id', columns='stock_id', values='target')

corr = train_p.corr()

# %%
ids = corr.index

kmeans = KMeans(n_clusters=7, random_state=0).fit(corr.values)
print(kmeans.labels_)

l = []
for n in range(7):
    l.append ( [ (x-1) for x in ( (ids+1)*(kmeans.labels_ == n)) if x > 0] )
# Out:
# [1 0 4 2 1 1 2 4 6 2 1 0 4 4 1 1 1 2 4 4 4 0 1 1 3 1 1 4 3 4 3 4 4 1 3 3 4
#  3 4 1 4 1 4 4 1 0 4 4 1 0 0 3 3 3 2 0 2 4 1 4 4 1 4 1 0 3 3 0 3 0 6 5 3 3
#  0 1 2 0 3 3 3 4 1 1 0 2 3 3 1 0 1 4 4 4 4 4 1 3 1 0 1 4 1 0 1 4 1 0 4 0 4
#  0]

# %%
mat = []
matTest = []

n = 0
for ind in l:
    print(ind)
    newDf = train.loc[train['stock_id'].isin(ind) ]
    newDf = newDf.groupby(['time_id']).agg(np.nanmean)
    newDf.loc[:,'stock_id'] = str(n)+'c1'
    mat.append ( newDf )
    
    newDf = test.loc[test['stock_id'].isin(ind) ]    
    newDf = newDf.groupby(['time_id']).agg(np.nanmean)
    newDf.loc[:,'stock_id'] = str(n)+'c1'
    matTest.append ( newDf )
    
    n+=1
    
mat1 = pd.concat(mat).reset_index()
mat1.drop(columns=['target'],inplace=True)

mat2 = pd.concat(matTest).reset_index()
# Out:
# [1, 11, 22, 50, 55, 56, 62, 73, 76, 78, 84, 87, 96, 101, 112, 116, 122, 124, 126]
# [0, 4, 5, 10, 15, 16, 17, 23, 26, 28, 29, 36, 42, 44, 48, 53, 66, 69, 72, 85, 94, 95, 100, 102, 109, 111, 113, 115, 118, 120]
# [3, 6, 9, 18, 61, 63, 86, 97]
# [27, 31, 33, 37, 38, 40, 58, 59, 60, 74, 75, 77, 82, 83, 88, 89, 90, 98, 99, 110]
# [2, 7, 13, 14, 19, 20, 21, 30, 32, 34, 35, 39, 41, 43, 46, 47, 51, 52, 64, 67, 68, 70, 93, 103, 104, 105, 107, 108, 114, 119, 123, 125]
# [81]
# [8, 80]

# %%
mat2 = pd.concat([mat2,mat1.loc[mat1.time_id==5]])
mat1 = mat1.pivot(index='time_id', columns='stock_id')
mat1.columns = ["_".join(x) for x in mat1.columns.ravel()]
mat1.reset_index(inplace=True)

mat2 = mat2.pivot(index='time_id', columns='stock_id')
mat2.columns = ["_".join(x) for x in mat2.columns.ravel()]
mat2.reset_index(inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   import sys

# %%
mat1.head()
# Out:
#    time_id  wap1_sum_0c1  wap1_sum_1c1  wap1_sum_2c1  wap1_sum_3c1  \
# 0        5    454.259460    450.296722    410.733185    350.107635
# 1       11    338.439728    320.296692    278.055267    233.907928
# 2       16    352.636505    360.082367    347.626770    256.215057
# 3       31    312.892395    302.954620    298.578033    231.109253
# 4       62    327.286407    314.466064    315.001099    210.724350
#
#    wap1_sum_4c1  wap1_sum_5c1  wap1_sum_6c1  wap1_std_0c1  wap1_std_1c1  ...  \
# 0    506.105530    537.815308    476.310425      0.001151      0.000885  ...
# 1    358.379181    281.177979    423.141602      0.000564      0.000475  ...
# 2    420.425507    355.364594    284.772736      0.000620      0.000490  ...
# 3    343.913910    449.594482    366.892456      0.000597      0.000615  ...
# 4    355.398346    218.791824    407.402344      0.000536      0.000439  ...
#
#    size_tau2_200_4c1  size_tau2_200_5c1  size_tau2_200_6c1  size_tau2_d_0c1  \
# 0           0.044431           0.044926           0.041189        -0.024915
# 1           0.063868           0.051484           0.037159        -0.034569
# 2           0.060912           0.036405           0.065579        -0.033426
# 3           0.076921           0.037837           0.045045        -0.042717
# 4           0.070177           0.076425           0.037661        -0.037143
#
#    size_tau2_d_1c1  size_tau2_d_2c1  size_tau2_d_3c1  size_tau2_d_4c1  \
# 0        -0.024369        -0.027101        -0.033393        -0.023273
# 1        -0.033599        -0.037332        -0.052039        -0.033454
# 2        -0.037183        -0.027899        -0.049481        -0.031906
# 3        -0.038160        -0.032851        -0.045086        -0.040292
# 4        -0.037902        -0.035379        -0.047943        -0.036759
#
#    size_tau2_d_5c1  size_tau2_d_6c1
# 0        -0.023533        -0.021575
# 1        -0.026968        -0.019464
# 2        -0.019069        -0.034351
# 3        -0.019820        -0.023595
# 4        -0.040032        -0.019727
#
# [5 rows x 1373 columns]

# %%
mat2.head()
# Out:
#    time_id  wap1_sum_0c1  wap1_sum_1c1  wap1_sum_2c1  wap1_sum_3c1  \
# 0        4           NaN      3.001215           NaN           NaN
# 1        5     454.25946    450.296722    410.733185    350.107635
# 2       32           NaN           NaN           NaN           NaN
# 3       34           NaN           NaN           NaN           NaN
#
#    wap1_sum_4c1  wap1_sum_5c1  wap1_sum_6c1  wap1_std_0c1  wap1_std_1c1  ...  \
# 0           NaN           NaN           NaN           NaN      0.000170  ...
# 1     506.10553    537.815308    476.310425      0.001151      0.000885  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
#
#    size_tau2_200_4c1  size_tau2_200_5c1  size_tau2_200_6c1  size_tau2_d_0c1  \
# 0                NaN                NaN                NaN              NaN
# 1           0.044431           0.044926           0.041189        -0.024915
# 2                NaN                NaN                NaN              NaN
# 3                NaN                NaN                NaN              NaN
#
#    size_tau2_d_1c1  size_tau2_d_2c1  size_tau2_d_3c1  size_tau2_d_4c1  \
# 0        -0.128306              NaN              NaN              NaN
# 1        -0.024369        -0.027101        -0.033393        -0.023273
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
#
#    size_tau2_d_5c1  size_tau2_d_6c1
# 0              NaN              NaN
# 1        -0.023533        -0.021575
# 2              NaN              NaN
# 3              NaN              NaN
#
# [4 rows x 1373 columns]

# %%
mat1.columns.tolist()
# Out:
# ['time_id',
#  'wap1_sum_0c1',
#  'wap1_sum_1c1',
#  'wap1_sum_2c1',
#  'wap1_sum_3c1',
#  'wap1_sum_4c1',
#  'wap1_sum_5c1',
#  'wap1_sum_6c1',
#  'wap1_std_0c1',
#  'wap1_std_1c1',
#  'wap1_std_2c1',
#  'wap1_std_3c1',
#  'wap1_std_4c1',
#  'wap1_std_5c1',
#  'wap1_std_6c1',
#  'wap2_sum_0c1',
#  'wap2_sum_1c1',
#  'wap2_sum_2c1',
#  'wap2_sum_3c1',
#  'wap2_sum_4c1',
#  'wap2_sum_5c1',
#  'wap2_sum_6c1',
#  'wap2_std_0c1',
#  'wap2_std_1c1',
#  'wap2_std_2c1',
#  'wap2_std_3c1',
#  'wap2_std_4c1',
#  'wap2_std_5c1',
#  'wap2_std_6c1',
#  'wap3_sum_0c1',
#  'wap3_sum_1c1',
#  'wap3_sum_2c1',
#  'wap3_sum_3c1',
#  'wap3_sum_4c1',
#  'wap3_sum_5c1',
#  'wap3_sum_6c1',
#  'wap3_std_0c1',
#  'wap3_std_1c1',
#  'wap3_std_2c1',
#  'wap3_std_3c1',
#  'wap3_std_4c1',
#  'wap3_std_5c1',
#  'wap3_std_6c1',
#  'wap4_sum_0c1',
#  'wap4_sum_1c1',
#  'wap4_sum_2c1',
#  'wap4_sum_3c1',
#  'wap4_sum_4c1',
#  'wap4_sum_5c1',
#  'wap4_sum_6c1',
#  'wap4_std_0c1',
#  'wap4_std_1c1',
#  'wap4_std_2c1',
#  'wap4_std_3c1',
#  'wap4_std_4c1',
#  'wap4_std_5c1',
#  'wap4_std_6c1',
#  'log_return1_realized_volatility_0c1',
#  'log_return1_realized_volatility_1c1',
#  'log_return1_realized_volatility_2c1',
#  'log_return1_realized_volatility_3c1',
#  'log_return1_realized_volatility_4c1',
#  'log_return1_realized_volatility_5c1',
#  'log_return1_realized_volatility_6c1',
#  'log_return2_realized_volatility_0c1',
#  'log_return2_realized_volatility_1c1',
#  'log_return2_realized_volatility_2c1',
#  'log_return2_realized_volatility_3c1',
#  'log_return2_realized_volatility_4c1',
#  'log_return2_realized_volatility_5c1',
#  'log_return2_realized_volatility_6c1',
#  'log_return3_realized_volatility_0c1',
#  'log_return3_realized_volatility_1c1',
#  'log_return3_realized_volatility_2c1',
#  'log_return3_realized_volatility_3c1',
#  'log_return3_realized_volatility_4c1',
#  'log_return3_realized_volatility_5c1',
#  'log_return3_realized_volatility_6c1',
#  'log_return4_realized_volatility_0c1',
#  'log_return4_realized_volatility_1c1',
#  'log_return4_realized_volatility_2c1',
#  'log_return4_realized_volatility_3c1',
#  'log_return4_realized_volatility_4c1',
#  'log_return4_realized_volatility_5c1',
#  'log_return4_realized_volatility_6c1',
#  'wap_balance_sum_0c1',
#  'wap_balance_sum_1c1',
#  'wap_balance_sum_2c1',
#  'wap_balance_sum_3c1',
#  'wap_balance_sum_4c1',
#  'wap_balance_sum_5c1',
#  'wap_balance_sum_6c1',
#  'wap_balance_amax_0c1',
#  'wap_balance_amax_1c1',
#  'wap_balance_amax_2c1',
#  'wap_balance_amax_3c1',
#  'wap_balance_amax_4c1',
#  'wap_balance_amax_5c1',
#  'wap_balance_amax_6c1',
#  'price_spread_sum_0c1',
#  'price_spread_sum_1c1',
#  'price_spread_sum_2c1',
#  'price_spread_sum_3c1',
#  'price_spread_sum_4c1',
#  'price_spread_sum_5c1',
#  'price_spread_sum_6c1',
#  'price_spread_amax_0c1',
#  'price_spread_amax_1c1',
#  'price_spread_amax_2c1',
#  'price_spread_amax_3c1',
#  'price_spread_amax_4c1',
#  'price_spread_amax_5c1',
#  'price_spread_amax_6c1',
#  'price_spread2_sum_0c1',
#  'price_spread2_sum_1c1',
#  'price_spread2_sum_2c1',
#  'price_spread2_sum_3c1',
#  'price_spread2_sum_4c1',
#  'price_spread2_sum_5c1',
#  'price_spread2_sum_6c1',
#  'price_spread2_amax_0c1',
#  'price_spread2_amax_1c1',
#  'price_spread2_amax_2c1',
#  'price_spread2_amax_3c1',
#  'price_spread2_amax_4c1',
#  'price_spread2_amax_5c1',
#  'price_spread2_amax_6c1',
#  'bid_spread_sum_0c1',
#  'bid_spread_sum_1c1',
#  'bid_spread_sum_2c1',
#  'bid_spread_sum_3c1',
#  'bid_spread_sum_4c1',
#  'bid_spread_sum_5c1',
#  'bid_spread_sum_6c1',
#  'bid_spread_amax_0c1',
#  'bid_spread_amax_1c1',
#  'bid_spread_amax_2c1',
#  'bid_spread_amax_3c1',
#  'bid_spread_amax_4c1',
#  'bid_spread_amax_5c1',
#  'bid_spread_amax_6c1',
#  'ask_spread_sum_0c1',
#  'ask_spread_sum_1c1',
#  'ask_spread_sum_2c1',
#  'ask_spread_sum_3c1',
#  'ask_spread_sum_4c1',
#  'ask_spread_sum_5c1',
#  'ask_spread_sum_6c1',
#  'ask_spread_amax_0c1',
#  'ask_spread_amax_1c1',
#  'ask_spread_amax_2c1',
#  'ask_spread_amax_3c1',
#  'ask_spread_amax_4c1',
#  'ask_spread_amax_5c1',
#  'ask_spread_amax_6c1',
#  'total_volume_sum_0c1',
#  'total_volume_sum_1c1',
#  'total_volume_sum_2c1',
#  'total_volume_sum_3c1',
#  'total_volume_sum_4c1',
#  'total_volume_sum_5c1',
#  'total_volume_sum_6c1',
#  'total_volume_amax_0c1',
#  'total_volume_amax_1c1',
#  'total_volume_amax_2c1',
#  'total_volume_amax_3c1',
#  'total_volume_amax_4c1',
#  'total_volume_amax_5c1',
#  'total_volume_amax_6c1',
#  'volume_imbalance_sum_0c1',
#  'volume_imbalance_sum_1c1',
#  'volume_imbalance_sum_2c1',
#  'volume_imbalance_sum_3c1',
#  'volume_imbalance_sum_4c1',
#  'volume_imbalance_sum_5c1',
#  'volume_imbalance_sum_6c1',
#  'volume_imbalance_amax_0c1',
#  'volume_imbalance_amax_1c1',
#  'volume_imbalance_amax_2c1',
#  'volume_imbalance_amax_3c1',
#  'volume_imbalance_amax_4c1',
#  'volume_imbalance_amax_5c1',
#  'volume_imbalance_amax_6c1',
#  'bid_ask_spread_sum_0c1',
#  'bid_ask_spread_sum_1c1',
#  'bid_ask_spread_sum_2c1',
#  'bid_ask_spread_sum_3c1',
#  'bid_ask_spread_sum_4c1',
#  'bid_ask_spread_sum_5c1',
#  'bid_ask_spread_sum_6c1',
#  'bid_ask_spread_amax_0c1',
#  'bid_ask_spread_amax_1c1',
#  'bid_ask_spread_amax_2c1',
#  'bid_ask_spread_amax_3c1',
#  'bid_ask_spread_amax_4c1',
#  'bid_ask_spread_amax_5c1',
#  'bid_ask_spread_amax_6c1',
#  'bollinger_band_balance1_sum_0c1',
#  'bollinger_band_balance1_sum_1c1',
#  'bollinger_band_balance1_sum_2c1',
#  'bollinger_band_balance1_sum_3c1',
#  'bollinger_band_balance1_sum_4c1',
#  'bollinger_band_balance1_sum_5c1',
#  'bollinger_band_balance1_sum_6c1',
#  'bollinger_band_balance1_amax_0c1',
#  'bollinger_band_balance1_amax_1c1',
#  'bollinger_band_balance1_amax_2c1',
#  'bollinger_band_balance1_amax_3c1',
#  'bollinger_band_balance1_amax_4c1',
#  'bollinger_band_balance1_amax_5c1',
#  'bollinger_band_balance1_amax_6c1',
#  'log_return1_realized_volatility_500_0c1',
#  'log_return1_realized_volatility_500_1c1',
#  'log_return1_realized_volatility_500_2c1',
#  'log_return1_realized_volatility_500_3c1',
#  'log_return1_realized_volatility_500_4c1',
#  'log_return1_realized_volatility_500_5c1',
#  'log_return1_realized_volatility_500_6c1',
#  'log_return2_realized_volatility_500_0c1',
#  'log_return2_realized_volatility_500_1c1',
#  'log_return2_realized_volatility_500_2c1',
#  'log_return2_realized_volatility_500_3c1',
#  'log_return2_realized_volatility_500_4c1',
#  'log_return2_realized_volatility_500_5c1',
#  'log_return2_realized_volatility_500_6c1',
#  'log_return3_realized_volatility_500_0c1',
#  'log_return3_realized_volatility_500_1c1',
#  'log_return3_realized_volatility_500_2c1',
#  'log_return3_realized_volatility_500_3c1',
#  'log_return3_realized_volatility_500_4c1',
#  'log_return3_realized_volatility_500_5c1',
#  'log_return3_realized_volatility_500_6c1',
#  'log_return4_realized_volatility_500_0c1',
#  'log_return4_realized_volatility_500_1c1',
#  'log_return4_realized_volatility_500_2c1',
#  'log_return4_realized_volatility_500_3c1',
#  'log_return4_realized_volatility_500_4c1',
#  'log_return4_realized_volatility_500_5c1',
#  'log_return4_realized_volatility_500_6c1',
#  'log_return1_realized_volatility_400_0c1',
#  'log_return1_realized_volatility_400_1c1',
#  'log_return1_realized_volatility_400_2c1',
#  'log_return1_realized_volatility_400_3c1',
#  'log_return1_realized_volatility_400_4c1',
#  'log_return1_realized_volatility_400_5c1',
#  'log_return1_realized_volatility_400_6c1',
#  'log_return2_realized_volatility_400_0c1',
#  'log_return2_realized_volatility_400_1c1',
#  'log_return2_realized_volatility_400_2c1',
#  'log_return2_realized_volatility_400_3c1',
#  'log_return2_realized_volatility_400_4c1',
#  'log_return2_realized_volatility_400_5c1',
#  'log_return2_realized_volatility_400_6c1',
#  'log_return3_realized_volatility_400_0c1',
#  'log_return3_realized_volatility_400_1c1',
#  'log_return3_realized_volatility_400_2c1',
#  'log_return3_realized_volatility_400_3c1',
#  'log_return3_realized_volatility_400_4c1',
#  'log_return3_realized_volatility_400_5c1',
#  'log_return3_realized_volatility_400_6c1',
#  'log_return4_realized_volatility_400_0c1',
#  'log_return4_realized_volatility_400_1c1',
#  'log_return4_realized_volatility_400_2c1',
#  'log_return4_realized_volatility_400_3c1',
#  'log_return4_realized_volatility_400_4c1',
#  'log_return4_realized_volatility_400_5c1',
#  'log_return4_realized_volatility_400_6c1',
#  'log_return1_realized_volatility_300_0c1',
#  'log_return1_realized_volatility_300_1c1',
#  'log_return1_realized_volatility_300_2c1',
#  'log_return1_realized_volatility_300_3c1',
#  'log_return1_realized_volatility_300_4c1',
#  'log_return1_realized_volatility_300_5c1',
#  'log_return1_realized_volatility_300_6c1',
#  'log_return2_realized_volatility_300_0c1',
#  'log_return2_realized_volatility_300_1c1',
#  'log_return2_realized_volatility_300_2c1',
#  'log_return2_realized_volatility_300_3c1',
#  'log_return2_realized_volatility_300_4c1',
#  'log_return2_realized_volatility_300_5c1',
#  'log_return2_realized_volatility_300_6c1',
#  'log_return3_realized_volatility_300_0c1',
#  'log_return3_realized_volatility_300_1c1',
#  'log_return3_realized_volatility_300_2c1',
#  'log_return3_realized_volatility_300_3c1',
#  'log_return3_realized_volatility_300_4c1',
#  'log_return3_realized_volatility_300_5c1',
#  'log_return3_realized_volatility_300_6c1',
#  'log_return4_realized_volatility_300_0c1',
#  'log_return4_realized_volatility_300_1c1',
#  'log_return4_realized_volatility_300_2c1',
#  'log_return4_realized_volatility_300_3c1',
#  'log_return4_realized_volatility_300_4c1',
#  'log_return4_realized_volatility_300_5c1',
#  'log_return4_realized_volatility_300_6c1',
#  'log_return1_realized_volatility_200_0c1',
#  'log_return1_realized_volatility_200_1c1',
#  'log_return1_realized_volatility_200_2c1',
#  'log_return1_realized_volatility_200_3c1',
#  'log_return1_realized_volatility_200_4c1',
#  'log_return1_realized_volatility_200_5c1',
#  'log_return1_realized_volatility_200_6c1',
#  'log_return2_realized_volatility_200_0c1',
#  'log_return2_realized_volatility_200_1c1',
#  'log_return2_realized_volatility_200_2c1',
#  'log_return2_realized_volatility_200_3c1',
#  'log_return2_realized_volatility_200_4c1',
#  'log_return2_realized_volatility_200_5c1',
#  'log_return2_realized_volatility_200_6c1',
#  'log_return3_realized_volatility_200_0c1',
#  'log_return3_realized_volatility_200_1c1',
#  'log_return3_realized_volatility_200_2c1',
#  'log_return3_realized_volatility_200_3c1',
#  'log_return3_realized_volatility_200_4c1',
#  'log_return3_realized_volatility_200_5c1',
#  'log_return3_realized_volatility_200_6c1',
#  'log_return4_realized_volatility_200_0c1',
#  'log_return4_realized_volatility_200_1c1',
#  'log_return4_realized_volatility_200_2c1',
#  'log_return4_realized_volatility_200_3c1',
#  'log_return4_realized_volatility_200_4c1',
#  'log_return4_realized_volatility_200_5c1',
#  'log_return4_realized_volatility_200_6c1',
#  'log_return1_realized_volatility_100_0c1',
#  'log_return1_realized_volatility_100_1c1',
#  'log_return1_realized_volatility_100_2c1',
#  'log_return1_realized_volatility_100_3c1',
#  'log_return1_realized_volatility_100_4c1',
#  'log_return1_realized_volatility_100_5c1',
#  'log_return1_realized_volatility_100_6c1',
#  'log_return2_realized_volatility_100_0c1',
#  'log_return2_realized_volatility_100_1c1',
#  'log_return2_realized_volatility_100_2c1',
#  'log_return2_realized_volatility_100_3c1',
#  'log_return2_realized_volatility_100_4c1',
#  'log_return2_realized_volatility_100_5c1',
#  'log_return2_realized_volatility_100_6c1',
#  'log_return3_realized_volatility_100_0c1',
#  'log_return3_realized_volatility_100_1c1',
#  'log_return3_realized_volatility_100_2c1',
#  'log_return3_realized_volatility_100_3c1',
#  'log_return3_realized_volatility_100_4c1',
#  'log_return3_realized_volatility_100_5c1',
#  'log_return3_realized_volatility_100_6c1',
#  'log_return4_realized_volatility_100_0c1',
#  'log_return4_realized_volatility_100_1c1',
#  'log_return4_realized_volatility_100_2c1',
#  'log_return4_realized_volatility_100_3c1',
#  'log_return4_realized_volatility_100_4c1',
#  'log_return4_realized_volatility_100_5c1',
#  'log_return4_realized_volatility_100_6c1',
#  'trade_log_return_realized_volatility_0c1',
#  'trade_log_return_realized_volatility_1c1',
#  'trade_log_return_realized_volatility_2c1',
#  'trade_log_return_realized_volatility_3c1',
#  'trade_log_return_realized_volatility_4c1',
#  'trade_log_return_realized_volatility_5c1',
#  'trade_log_return_realized_volatility_6c1',
#  'trade_seconds_in_bucket_count_unique_0c1',
#  'trade_seconds_in_bucket_count_unique_1c1',
#  'trade_seconds_in_bucket_count_unique_2c1',
#  'trade_seconds_in_bucket_count_unique_3c1',
#  'trade_seconds_in_bucket_count_unique_4c1',
#  'trade_seconds_in_bucket_count_unique_5c1',
#  'trade_seconds_in_bucket_count_unique_6c1',
#  'trade_size_sum_0c1',
#  'trade_size_sum_1c1',
#  'trade_size_sum_2c1',
#  'trade_size_sum_3c1',
#  'trade_size_sum_4c1',
#  'trade_size_sum_5c1',
#  'trade_size_sum_6c1',
#  'trade_size_amax_0c1',
#  'trade_size_amax_1c1',
#  'trade_size_amax_2c1',
#  'trade_size_amax_3c1',
#  'trade_size_amax_4c1',
#  'trade_size_amax_5c1',
#  'trade_size_amax_6c1',
#  'trade_size_amin_0c1',
#  'trade_size_amin_1c1',
#  'trade_size_amin_2c1',
#  'trade_size_amin_3c1',
#  'trade_size_amin_4c1',
#  'trade_size_amin_5c1',
#  'trade_size_amin_6c1',
#  'trade_order_count_sum_0c1',
#  'trade_order_count_sum_1c1',
#  'trade_order_count_sum_2c1',
#  'trade_order_count_sum_3c1',
#  'trade_order_count_sum_4c1',
#  'trade_order_count_sum_5c1',
#  'trade_order_count_sum_6c1',
#  'trade_order_count_amax_0c1',
#  'trade_order_count_amax_1c1',
#  'trade_order_count_amax_2c1',
#  'trade_order_count_amax_3c1',
#  'trade_order_count_amax_4c1',
#  'trade_order_count_amax_5c1',
#  'trade_order_count_amax_6c1',
#  'trade_amount_sum_0c1',
#  'trade_amount_sum_1c1',
#  'trade_amount_sum_2c1',
#  'trade_amount_sum_3c1',
#  'trade_amount_sum_4c1',
#  'trade_amount_sum_5c1',
#  'trade_amount_sum_6c1',
#  'trade_amount_amax_0c1',
#  'trade_amount_amax_1c1',
#  'trade_amount_amax_2c1',
#  'trade_amount_amax_3c1',
#  'trade_amount_amax_4c1',
#  'trade_amount_amax_5c1',
#  'trade_amount_amax_6c1',
#  'trade_amount_amin_0c1',
#  'trade_amount_amin_1c1',
#  'trade_amount_amin_2c1',
#  'trade_amount_amin_3c1',
#  'trade_amount_amin_4c1',
#  'trade_amount_amin_5c1',
#  'trade_amount_amin_6c1',
#  'trade_tendency_0c1',
#  'trade_tendency_1c1',
#  'trade_tendency_2c1',
#  'trade_tendency_3c1',
#  'trade_tendency_4c1',
#  'trade_tendency_5c1',
#  'trade_tendency_6c1',
#  'trade_f_max_0c1',
#  'trade_f_max_1c1',
#  'trade_f_max_2c1',
#  'trade_f_max_3c1',
#  'trade_f_max_4c1',
#  'trade_f_max_5c1',
#  'trade_f_max_6c1',
#  'trade_f_min_0c1',
#  'trade_f_min_1c1',
#  'trade_f_min_2c1',
#  'trade_f_min_3c1',
#  'trade_f_min_4c1',
#  'trade_f_min_5c1',
#  'trade_f_min_6c1',
#  'trade_df_max_0c1',
#  'trade_df_max_1c1',
#  'trade_df_max_2c1',
#  'trade_df_max_3c1',
#  'trade_df_max_4c1',
#  'trade_df_max_5c1',
#  'trade_df_max_6c1',
#  'trade_df_min_0c1',
#  'trade_df_min_1c1',
#  'trade_df_min_2c1',
#  'trade_df_min_3c1',
#  'trade_df_min_4c1',
#  'trade_df_min_5c1',
#  'trade_df_min_6c1',
#  'trade_abs_diff_0c1',
#  'trade_abs_diff_1c1',
#  'trade_abs_diff_2c1',
#  'trade_abs_diff_3c1',
#  'trade_abs_diff_4c1',
#  'trade_abs_diff_5c1',
#  'trade_abs_diff_6c1',
#  'trade_energy_0c1',
#  'trade_energy_1c1',
#  'trade_energy_2c1',
#  'trade_energy_3c1',
#  'trade_energy_4c1',
#  'trade_energy_5c1',
#  'trade_energy_6c1',
#  'trade_iqr_p_0c1',
#  'trade_iqr_p_1c1',
#  'trade_iqr_p_2c1',
#  'trade_iqr_p_3c1',
#  'trade_iqr_p_4c1',
#  'trade_iqr_p_5c1',
#  'trade_iqr_p_6c1',
#  'trade_abs_diff_v_0c1',
#  'trade_abs_diff_v_1c1',
#  'trade_abs_diff_v_2c1',
#  'trade_abs_diff_v_3c1',
#  'trade_abs_diff_v_4c1',
#  'trade_abs_diff_v_5c1',
#  'trade_abs_diff_v_6c1',
#  'trade_energy_v_0c1',
#  'trade_energy_v_1c1',
#  'trade_energy_v_2c1',
#  'trade_energy_v_3c1',
#  'trade_energy_v_4c1',
#  'trade_energy_v_5c1',
#  'trade_energy_v_6c1',
#  'trade_iqr_p_v_0c1',
#  'trade_iqr_p_v_1c1',
#  'trade_iqr_p_v_2c1',
#  'trade_iqr_p_v_3c1',
#  'trade_iqr_p_v_4c1',
#  'trade_iqr_p_v_5c1',
#  'trade_iqr_p_v_6c1',
#  'trade_log_return_realized_volatility_500_0c1',
#  'trade_log_return_realized_volatility_500_1c1',
#  'trade_log_return_realized_volatility_500_2c1',
#  'trade_log_return_realized_volatility_500_3c1',
#  'trade_log_return_realized_volatility_500_4c1',
#  'trade_log_return_realized_volatility_500_5c1',
#  'trade_log_return_realized_volatility_500_6c1',
#  'trade_seconds_in_bucket_count_unique_500_0c1',
#  'trade_seconds_in_bucket_count_unique_500_1c1',
#  'trade_seconds_in_bucket_count_unique_500_2c1',
#  'trade_seconds_in_bucket_count_unique_500_3c1',
#  'trade_seconds_in_bucket_count_unique_500_4c1',
#  'trade_seconds_in_bucket_count_unique_500_5c1',
#  'trade_seconds_in_bucket_count_unique_500_6c1',
#  'trade_size_sum_500_0c1',
#  'trade_size_sum_500_1c1',
#  'trade_size_sum_500_2c1',
#  'trade_size_sum_500_3c1',
#  'trade_size_sum_500_4c1',
#  'trade_size_sum_500_5c1',
#  'trade_size_sum_500_6c1',
#  'trade_order_count_sum_500_0c1',
#  'trade_order_count_sum_500_1c1',
#  'trade_order_count_sum_500_2c1',
#  'trade_order_count_sum_500_3c1',
#  'trade_order_count_sum_500_4c1',
#  'trade_order_count_sum_500_5c1',
#  'trade_order_count_sum_500_6c1',
#  'trade_log_return_realized_volatility_400_0c1',
#  'trade_log_return_realized_volatility_400_1c1',
#  'trade_log_return_realized_volatility_400_2c1',
#  'trade_log_return_realized_volatility_400_3c1',
#  'trade_log_return_realized_volatility_400_4c1',
#  'trade_log_return_realized_volatility_400_5c1',
#  'trade_log_return_realized_volatility_400_6c1',
#  'trade_seconds_in_bucket_count_unique_400_0c1',
#  'trade_seconds_in_bucket_count_unique_400_1c1',
#  'trade_seconds_in_bucket_count_unique_400_2c1',
#  'trade_seconds_in_bucket_count_unique_400_3c1',
#  'trade_seconds_in_bucket_count_unique_400_4c1',
#  'trade_seconds_in_bucket_count_unique_400_5c1',
#  'trade_seconds_in_bucket_count_unique_400_6c1',
#  'trade_size_sum_400_0c1',
#  'trade_size_sum_400_1c1',
#  'trade_size_sum_400_2c1',
#  'trade_size_sum_400_3c1',
#  'trade_size_sum_400_4c1',
#  'trade_size_sum_400_5c1',
#  'trade_size_sum_400_6c1',
#  'trade_order_count_sum_400_0c1',
#  'trade_order_count_sum_400_1c1',
#  'trade_order_count_sum_400_2c1',
#  'trade_order_count_sum_400_3c1',
#  'trade_order_count_sum_400_4c1',
#  'trade_order_count_sum_400_5c1',
#  'trade_order_count_sum_400_6c1',
#  'trade_log_return_realized_volatility_300_0c1',
#  'trade_log_return_realized_volatility_300_1c1',
#  'trade_log_return_realized_volatility_300_2c1',
#  'trade_log_return_realized_volatility_300_3c1',
#  'trade_log_return_realized_volatility_300_4c1',
#  'trade_log_return_realized_volatility_300_5c1',
#  'trade_log_return_realized_volatility_300_6c1',
#  'trade_seconds_in_bucket_count_unique_300_0c1',
#  'trade_seconds_in_bucket_count_unique_300_1c1',
#  'trade_seconds_in_bucket_count_unique_300_2c1',
#  'trade_seconds_in_bucket_count_unique_300_3c1',
#  'trade_seconds_in_bucket_count_unique_300_4c1',
#  'trade_seconds_in_bucket_count_unique_300_5c1',
#  'trade_seconds_in_bucket_count_unique_300_6c1',
#  'trade_size_sum_300_0c1',
#  'trade_size_sum_300_1c1',
#  'trade_size_sum_300_2c1',
#  'trade_size_sum_300_3c1',
#  'trade_size_sum_300_4c1',
#  'trade_size_sum_300_5c1',
#  'trade_size_sum_300_6c1',
#  'trade_order_count_sum_300_0c1',
#  'trade_order_count_sum_300_1c1',
#  'trade_order_count_sum_300_2c1',
#  'trade_order_count_sum_300_3c1',
#  'trade_order_count_sum_300_4c1',
#  'trade_order_count_sum_300_5c1',
#  'trade_order_count_sum_300_6c1',
#  'trade_log_return_realized_volatility_200_0c1',
#  'trade_log_return_realized_volatility_200_1c1',
#  'trade_log_return_realized_volatility_200_2c1',
#  'trade_log_return_realized_volatility_200_3c1',
#  'trade_log_return_realized_volatility_200_4c1',
#  'trade_log_return_realized_volatility_200_5c1',
#  'trade_log_return_realized_volatility_200_6c1',
#  'trade_seconds_in_bucket_count_unique_200_0c1',
#  'trade_seconds_in_bucket_count_unique_200_1c1',
#  'trade_seconds_in_bucket_count_unique_200_2c1',
#  'trade_seconds_in_bucket_count_unique_200_3c1',
#  'trade_seconds_in_bucket_count_unique_200_4c1',
#  'trade_seconds_in_bucket_count_unique_200_5c1',
#  'trade_seconds_in_bucket_count_unique_200_6c1',
#  'trade_size_sum_200_0c1',
#  'trade_size_sum_200_1c1',
#  'trade_size_sum_200_2c1',
#  'trade_size_sum_200_3c1',
#  'trade_size_sum_200_4c1',
#  'trade_size_sum_200_5c1',
#  'trade_size_sum_200_6c1',
#  'trade_order_count_sum_200_0c1',
#  'trade_order_count_sum_200_1c1',
#  'trade_order_count_sum_200_2c1',
#  'trade_order_count_sum_200_3c1',
#  'trade_order_count_sum_200_4c1',
#  'trade_order_count_sum_200_5c1',
#  'trade_order_count_sum_200_6c1',
#  'trade_log_return_realized_volatility_100_0c1',
#  'trade_log_return_realized_volatility_100_1c1',
#  'trade_log_return_realized_volatility_100_2c1',
#  'trade_log_return_realized_volatility_100_3c1',
#  'trade_log_return_realized_volatility_100_4c1',
#  'trade_log_return_realized_volatility_100_5c1',
#  'trade_log_return_realized_volatility_100_6c1',
#  'trade_seconds_in_bucket_count_unique_100_0c1',
#  'trade_seconds_in_bucket_count_unique_100_1c1',
#  'trade_seconds_in_bucket_count_unique_100_2c1',
#  'trade_seconds_in_bucket_count_unique_100_3c1',
#  'trade_seconds_in_bucket_count_unique_100_4c1',
#  'trade_seconds_in_bucket_count_unique_100_5c1',
#  'trade_seconds_in_bucket_count_unique_100_6c1',
#  'trade_size_sum_100_0c1',
#  'trade_size_sum_100_1c1',
#  'trade_size_sum_100_2c1',
#  'trade_size_sum_100_3c1',
#  'trade_size_sum_100_4c1',
#  'trade_size_sum_100_5c1',
#  'trade_size_sum_100_6c1',
#  'trade_order_count_sum_100_0c1',
#  'trade_order_count_sum_100_1c1',
#  'trade_order_count_sum_100_2c1',
#  'trade_order_count_sum_100_3c1',
#  'trade_order_count_sum_100_4c1',
#  'trade_order_count_sum_100_5c1',
#  'trade_order_count_sum_100_6c1',
#  'log_return1_realized_volatility_mean_stock_0c1',
#  'log_return1_realized_volatility_mean_stock_1c1',
#  'log_return1_realized_volatility_mean_stock_2c1',
#  'log_return1_realized_volatility_mean_stock_3c1',
#  'log_return1_realized_volatility_mean_stock_4c1',
#  'log_return1_realized_volatility_mean_stock_5c1',
#  'log_return1_realized_volatility_mean_stock_6c1',
#  'log_return1_realized_volatility_std_stock_0c1',
#  'log_return1_realized_volatility_std_stock_1c1',
#  'log_return1_realized_volatility_std_stock_2c1',
#  'log_return1_realized_volatility_std_stock_3c1',
#  'log_return1_realized_volatility_std_stock_4c1',
#  'log_return1_realized_volatility_std_stock_5c1',
#  'log_return1_realized_volatility_std_stock_6c1',
#  'log_return1_realized_volatility_max_stock_0c1',
#  'log_return1_realized_volatility_max_stock_1c1',
#  'log_return1_realized_volatility_max_stock_2c1',
#  'log_return1_realized_volatility_max_stock_3c1',
#  'log_return1_realized_volatility_max_stock_4c1',
#  'log_return1_realized_volatility_max_stock_5c1',
#  'log_return1_realized_volatility_max_stock_6c1',
#  'log_return1_realized_volatility_min_stock_0c1',
#  'log_return1_realized_volatility_min_stock_1c1',
#  'log_return1_realized_volatility_min_stock_2c1',
#  'log_return1_realized_volatility_min_stock_3c1',
#  'log_return1_realized_volatility_min_stock_4c1',
#  'log_return1_realized_volatility_min_stock_5c1',
#  'log_return1_realized_volatility_min_stock_6c1',
#  'log_return2_realized_volatility_mean_stock_0c1',
#  'log_return2_realized_volatility_mean_stock_1c1',
#  'log_return2_realized_volatility_mean_stock_2c1',
#  'log_return2_realized_volatility_mean_stock_3c1',
#  'log_return2_realized_volatility_mean_stock_4c1',
#  'log_return2_realized_volatility_mean_stock_5c1',
#  'log_return2_realized_volatility_mean_stock_6c1',
#  'log_return2_realized_volatility_std_stock_0c1',
#  'log_return2_realized_volatility_std_stock_1c1',
#  'log_return2_realized_volatility_std_stock_2c1',
#  'log_return2_realized_volatility_std_stock_3c1',
#  'log_return2_realized_volatility_std_stock_4c1',
#  'log_return2_realized_volatility_std_stock_5c1',
#  'log_return2_realized_volatility_std_stock_6c1',
#  'log_return2_realized_volatility_max_stock_0c1',
#  'log_return2_realized_volatility_max_stock_1c1',
#  'log_return2_realized_volatility_max_stock_2c1',
#  'log_return2_realized_volatility_max_stock_3c1',
#  'log_return2_realized_volatility_max_stock_4c1',
#  'log_return2_realized_volatility_max_stock_5c1',
#  'log_return2_realized_volatility_max_stock_6c1',
#  'log_return2_realized_volatility_min_stock_0c1',
#  'log_return2_realized_volatility_min_stock_1c1',
#  'log_return2_realized_volatility_min_stock_2c1',
#  'log_return2_realized_volatility_min_stock_3c1',
#  'log_return2_realized_volatility_min_stock_4c1',
#  'log_return2_realized_volatility_min_stock_5c1',
#  'log_return2_realized_volatility_min_stock_6c1',
#  'log_return1_realized_volatility_400_mean_stock_0c1',
#  'log_return1_realized_volatility_400_mean_stock_1c1',
#  'log_return1_realized_volatility_400_mean_stock_2c1',
#  'log_return1_realized_volatility_400_mean_stock_3c1',
#  'log_return1_realized_volatility_400_mean_stock_4c1',
#  'log_return1_realized_volatility_400_mean_stock_5c1',
#  'log_return1_realized_volatility_400_mean_stock_6c1',
#  'log_return1_realized_volatility_400_std_stock_0c1',
#  'log_return1_realized_volatility_400_std_stock_1c1',
#  'log_return1_realized_volatility_400_std_stock_2c1',
#  'log_return1_realized_volatility_400_std_stock_3c1',
#  'log_return1_realized_volatility_400_std_stock_4c1',
#  'log_return1_realized_volatility_400_std_stock_5c1',
#  'log_return1_realized_volatility_400_std_stock_6c1',
#  'log_return1_realized_volatility_400_max_stock_0c1',
#  'log_return1_realized_volatility_400_max_stock_1c1',
#  'log_return1_realized_volatility_400_max_stock_2c1',
#  'log_return1_realized_volatility_400_max_stock_3c1',
#  'log_return1_realized_volatility_400_max_stock_4c1',
#  'log_return1_realized_volatility_400_max_stock_5c1',
#  'log_return1_realized_volatility_400_max_stock_6c1',
#  'log_return1_realized_volatility_400_min_stock_0c1',
#  'log_return1_realized_volatility_400_min_stock_1c1',
#  'log_return1_realized_volatility_400_min_stock_2c1',
#  'log_return1_realized_volatility_400_min_stock_3c1',
#  'log_return1_realized_volatility_400_min_stock_4c1',
#  'log_return1_realized_volatility_400_min_stock_5c1',
#  'log_return1_realized_volatility_400_min_stock_6c1',
#  'log_return2_realized_volatility_400_mean_stock_0c1',
#  'log_return2_realized_volatility_400_mean_stock_1c1',
#  'log_return2_realized_volatility_400_mean_stock_2c1',
#  'log_return2_realized_volatility_400_mean_stock_3c1',
#  'log_return2_realized_volatility_400_mean_stock_4c1',
#  'log_return2_realized_volatility_400_mean_stock_5c1',
#  'log_return2_realized_volatility_400_mean_stock_6c1',
#  'log_return2_realized_volatility_400_std_stock_0c1',
#  'log_return2_realized_volatility_400_std_stock_1c1',
#  'log_return2_realized_volatility_400_std_stock_2c1',
#  'log_return2_realized_volatility_400_std_stock_3c1',
#  'log_return2_realized_volatility_400_std_stock_4c1',
#  'log_return2_realized_volatility_400_std_stock_5c1',
#  'log_return2_realized_volatility_400_std_stock_6c1',
#  'log_return2_realized_volatility_400_max_stock_0c1',
#  'log_return2_realized_volatility_400_max_stock_1c1',
#  'log_return2_realized_volatility_400_max_stock_2c1',
#  'log_return2_realized_volatility_400_max_stock_3c1',
#  'log_return2_realized_volatility_400_max_stock_4c1',
#  'log_return2_realized_volatility_400_max_stock_5c1',
#  'log_return2_realized_volatility_400_max_stock_6c1',
#  'log_return2_realized_volatility_400_min_stock_0c1',
#  'log_return2_realized_volatility_400_min_stock_1c1',
#  'log_return2_realized_volatility_400_min_stock_2c1',
#  'log_return2_realized_volatility_400_min_stock_3c1',
#  'log_return2_realized_volatility_400_min_stock_4c1',
#  'log_return2_realized_volatility_400_min_stock_5c1',
#  'log_return2_realized_volatility_400_min_stock_6c1',
#  'log_return1_realized_volatility_300_mean_stock_0c1',
#  'log_return1_realized_volatility_300_mean_stock_1c1',
#  'log_return1_realized_volatility_300_mean_stock_2c1',
#  'log_return1_realized_volatility_300_mean_stock_3c1',
#  'log_return1_realized_volatility_300_mean_stock_4c1',
#  'log_return1_realized_volatility_300_mean_stock_5c1',
#  'log_return1_realized_volatility_300_mean_stock_6c1',
#  'log_return1_realized_volatility_300_std_stock_0c1',
#  'log_return1_realized_volatility_300_std_stock_1c1',
#  'log_return1_realized_volatility_300_std_stock_2c1',
#  'log_return1_realized_volatility_300_std_stock_3c1',
#  'log_return1_realized_volatility_300_std_stock_4c1',
#  'log_return1_realized_volatility_300_std_stock_5c1',
#  'log_return1_realized_volatility_300_std_stock_6c1',
#  'log_return1_realized_volatility_300_max_stock_0c1',
#  'log_return1_realized_volatility_300_max_stock_1c1',
#  'log_return1_realized_volatility_300_max_stock_2c1',
#  'log_return1_realized_volatility_300_max_stock_3c1',
#  'log_return1_realized_volatility_300_max_stock_4c1',
#  'log_return1_realized_volatility_300_max_stock_5c1',
#  'log_return1_realized_volatility_300_max_stock_6c1',
#  'log_return1_realized_volatility_300_min_stock_0c1',
#  'log_return1_realized_volatility_300_min_stock_1c1',
#  'log_return1_realized_volatility_300_min_stock_2c1',
#  'log_return1_realized_volatility_300_min_stock_3c1',
#  'log_return1_realized_volatility_300_min_stock_4c1',
#  'log_return1_realized_volatility_300_min_stock_5c1',
#  'log_return1_realized_volatility_300_min_stock_6c1',
#  'log_return2_realized_volatility_300_mean_stock_0c1',
#  'log_return2_realized_volatility_300_mean_stock_1c1',
#  'log_return2_realized_volatility_300_mean_stock_2c1',
#  'log_return2_realized_volatility_300_mean_stock_3c1',
#  'log_return2_realized_volatility_300_mean_stock_4c1',
#  'log_return2_realized_volatility_300_mean_stock_5c1',
#  'log_return2_realized_volatility_300_mean_stock_6c1',
#  'log_return2_realized_volatility_300_std_stock_0c1',
#  'log_return2_realized_volatility_300_std_stock_1c1',
#  'log_return2_realized_volatility_300_std_stock_2c1',
#  'log_return2_realized_volatility_300_std_stock_3c1',
#  'log_return2_realized_volatility_300_std_stock_4c1',
#  'log_return2_realized_volatility_300_std_stock_5c1',
#  'log_return2_realized_volatility_300_std_stock_6c1',
#  'log_return2_realized_volatility_300_max_stock_0c1',
#  'log_return2_realized_volatility_300_max_stock_1c1',
#  'log_return2_realized_volatility_300_max_stock_2c1',
#  'log_return2_realized_volatility_300_max_stock_3c1',
#  'log_return2_realized_volatility_300_max_stock_4c1',
#  'log_return2_realized_volatility_300_max_stock_5c1',
#  'log_return2_realized_volatility_300_max_stock_6c1',
#  'log_return2_realized_volatility_300_min_stock_0c1',
#  'log_return2_realized_volatility_300_min_stock_1c1',
#  'log_return2_realized_volatility_300_min_stock_2c1',
#  'log_return2_realized_volatility_300_min_stock_3c1',
#  'log_return2_realized_volatility_300_min_stock_4c1',
#  'log_return2_realized_volatility_300_min_stock_5c1',
#  'log_return2_realized_volatility_300_min_stock_6c1',
#  'log_return1_realized_volatility_200_mean_stock_0c1',
#  'log_return1_realized_volatility_200_mean_stock_1c1',
#  'log_return1_realized_volatility_200_mean_stock_2c1',
#  'log_return1_realized_volatility_200_mean_stock_3c1',
#  'log_return1_realized_volatility_200_mean_stock_4c1',
#  'log_return1_realized_volatility_200_mean_stock_5c1',
#  'log_return1_realized_volatility_200_mean_stock_6c1',
#  'log_return1_realized_volatility_200_std_stock_0c1',
#  'log_return1_realized_volatility_200_std_stock_1c1',
#  'log_return1_realized_volatility_200_std_stock_2c1',
#  'log_return1_realized_volatility_200_std_stock_3c1',
#  'log_return1_realized_volatility_200_std_stock_4c1',
#  'log_return1_realized_volatility_200_std_stock_5c1',
#  'log_return1_realized_volatility_200_std_stock_6c1',
#  'log_return1_realized_volatility_200_max_stock_0c1',
#  'log_return1_realized_volatility_200_max_stock_1c1',
#  'log_return1_realized_volatility_200_max_stock_2c1',
#  'log_return1_realized_volatility_200_max_stock_3c1',
#  'log_return1_realized_volatility_200_max_stock_4c1',
#  'log_return1_realized_volatility_200_max_stock_5c1',
#  'log_return1_realized_volatility_200_max_stock_6c1',
#  'log_return1_realized_volatility_200_min_stock_0c1',
#  'log_return1_realized_volatility_200_min_stock_1c1',
#  'log_return1_realized_volatility_200_min_stock_2c1',
#  'log_return1_realized_volatility_200_min_stock_3c1',
#  'log_return1_realized_volatility_200_min_stock_4c1',
#  'log_return1_realized_volatility_200_min_stock_5c1',
#  'log_return1_realized_volatility_200_min_stock_6c1',
#  'log_return2_realized_volatility_200_mean_stock_0c1',
#  'log_return2_realized_volatility_200_mean_stock_1c1',
#  'log_return2_realized_volatility_200_mean_stock_2c1',
#  'log_return2_realized_volatility_200_mean_stock_3c1',
#  'log_return2_realized_volatility_200_mean_stock_4c1',
#  'log_return2_realized_volatility_200_mean_stock_5c1',
#  'log_return2_realized_volatility_200_mean_stock_6c1',
#  'log_return2_realized_volatility_200_std_stock_0c1',
#  'log_return2_realized_volatility_200_std_stock_1c1',
#  'log_return2_realized_volatility_200_std_stock_2c1',
#  'log_return2_realized_volatility_200_std_stock_3c1',
#  'log_return2_realized_volatility_200_std_stock_4c1',
#  'log_return2_realized_volatility_200_std_stock_5c1',
#  'log_return2_realized_volatility_200_std_stock_6c1',
#  'log_return2_realized_volatility_200_max_stock_0c1',
#  'log_return2_realized_volatility_200_max_stock_1c1',
#  'log_return2_realized_volatility_200_max_stock_2c1',
#  'log_return2_realized_volatility_200_max_stock_3c1',
#  'log_return2_realized_volatility_200_max_stock_4c1',
#  'log_return2_realized_volatility_200_max_stock_5c1',
#  'log_return2_realized_volatility_200_max_stock_6c1',
#  'log_return2_realized_volatility_200_min_stock_0c1',
#  'log_return2_realized_volatility_200_min_stock_1c1',
#  'log_return2_realized_volatility_200_min_stock_2c1',
#  'log_return2_realized_volatility_200_min_stock_3c1',
#  'log_return2_realized_volatility_200_min_stock_4c1',
#  'log_return2_realized_volatility_200_min_stock_5c1',
#  'log_return2_realized_volatility_200_min_stock_6c1',
#  'trade_log_return_realized_volatility_mean_stock_0c1',
#  'trade_log_return_realized_volatility_mean_stock_1c1',
#  'trade_log_return_realized_volatility_mean_stock_2c1',
#  'trade_log_return_realized_volatility_mean_stock_3c1',
#  'trade_log_return_realized_volatility_mean_stock_4c1',
#  'trade_log_return_realized_volatility_mean_stock_5c1',
#  'trade_log_return_realized_volatility_mean_stock_6c1',
#  'trade_log_return_realized_volatility_std_stock_0c1',
#  'trade_log_return_realized_volatility_std_stock_1c1',
#  'trade_log_return_realized_volatility_std_stock_2c1',
#  'trade_log_return_realized_volatility_std_stock_3c1',
#  'trade_log_return_realized_volatility_std_stock_4c1',
#  'trade_log_return_realized_volatility_std_stock_5c1',
#  'trade_log_return_realized_volatility_std_stock_6c1',
#  'trade_log_return_realized_volatility_max_stock_0c1',
#  'trade_log_return_realized_volatility_max_stock_1c1',
#  'trade_log_return_realized_volatility_max_stock_2c1',
#  'trade_log_return_realized_volatility_max_stock_3c1',
#  'trade_log_return_realized_volatility_max_stock_4c1',
#  'trade_log_return_realized_volatility_max_stock_5c1',
#  'trade_log_return_realized_volatility_max_stock_6c1',
#  'trade_log_return_realized_volatility_min_stock_0c1',
#  'trade_log_return_realized_volatility_min_stock_1c1',
#  'trade_log_return_realized_volatility_min_stock_2c1',
#  'trade_log_return_realized_volatility_min_stock_3c1',
#  'trade_log_return_realized_volatility_min_stock_4c1',
#  'trade_log_return_realized_volatility_min_stock_5c1',
#  'trade_log_return_realized_volatility_min_stock_6c1',
#  'trade_log_return_realized_volatility_400_mean_stock_0c1',
#  'trade_log_return_realized_volatility_400_mean_stock_1c1',
#  'trade_log_return_realized_volatility_400_mean_stock_2c1',
#  'trade_log_return_realized_volatility_400_mean_stock_3c1',
#  'trade_log_return_realized_volatility_400_mean_stock_4c1',
#  'trade_log_return_realized_volatility_400_mean_stock_5c1',
#  'trade_log_return_realized_volatility_400_mean_stock_6c1',
#  'trade_log_return_realized_volatility_400_std_stock_0c1',
#  'trade_log_return_realized_volatility_400_std_stock_1c1',
#  'trade_log_return_realized_volatility_400_std_stock_2c1',
#  'trade_log_return_realized_volatility_400_std_stock_3c1',
#  'trade_log_return_realized_volatility_400_std_stock_4c1',
#  'trade_log_return_realized_volatility_400_std_stock_5c1',
#  'trade_log_return_realized_volatility_400_std_stock_6c1',
#  'trade_log_return_realized_volatility_400_max_stock_0c1',
#  'trade_log_return_realized_volatility_400_max_stock_1c1',
#  'trade_log_return_realized_volatility_400_max_stock_2c1',
#  'trade_log_return_realized_volatility_400_max_stock_3c1',
#  'trade_log_return_realized_volatility_400_max_stock_4c1',
#  'trade_log_return_realized_volatility_400_max_stock_5c1',
#  'trade_log_return_realized_volatility_400_max_stock_6c1',
#  'trade_log_return_realized_volatility_400_min_stock_0c1',
#  'trade_log_return_realized_volatility_400_min_stock_1c1',
#  'trade_log_return_realized_volatility_400_min_stock_2c1',
#  'trade_log_return_realized_volatility_400_min_stock_3c1',
#  'trade_log_return_realized_volatility_400_min_stock_4c1',
#  'trade_log_return_realized_volatility_400_min_stock_5c1',
#  'trade_log_return_realized_volatility_400_min_stock_6c1',
#  'trade_log_return_realized_volatility_300_mean_stock_0c1',
#  'trade_log_return_realized_volatility_300_mean_stock_1c1',
#  'trade_log_return_realized_volatility_300_mean_stock_2c1',
#  'trade_log_return_realized_volatility_300_mean_stock_3c1',
#  'trade_log_return_realized_volatility_300_mean_stock_4c1',
#  'trade_log_return_realized_volatility_300_mean_stock_5c1',
#  'trade_log_return_realized_volatility_300_mean_stock_6c1',
#  'trade_log_return_realized_volatility_300_std_stock_0c1',
#  'trade_log_return_realized_volatility_300_std_stock_1c1',
#  'trade_log_return_realized_volatility_300_std_stock_2c1',
#  'trade_log_return_realized_volatility_300_std_stock_3c1',
#  'trade_log_return_realized_volatility_300_std_stock_4c1',
#  'trade_log_return_realized_volatility_300_std_stock_5c1',
#  'trade_log_return_realized_volatility_300_std_stock_6c1',
#  'trade_log_return_realized_volatility_300_max_stock_0c1',
#  'trade_log_return_realized_volatility_300_max_stock_1c1',
#  'trade_log_return_realized_volatility_300_max_stock_2c1',
#  'trade_log_return_realized_volatility_300_max_stock_3c1',
#  'trade_log_return_realized_volatility_300_max_stock_4c1',
#  'trade_log_return_realized_volatility_300_max_stock_5c1',
#  'trade_log_return_realized_volatility_300_max_stock_6c1',
#  'trade_log_return_realized_volatility_300_min_stock_0c1',
#  'trade_log_return_realized_volatility_300_min_stock_1c1',
#  'trade_log_return_realized_volatility_300_min_stock_2c1',
#  'trade_log_return_realized_volatility_300_min_stock_3c1',
#  'trade_log_return_realized_volatility_300_min_stock_4c1',
#  'trade_log_return_realized_volatility_300_min_stock_5c1',
#  'trade_log_return_realized_volatility_300_min_stock_6c1',
#  'trade_log_return_realized_volatility_200_mean_stock_0c1',
#  'trade_log_return_realized_volatility_200_mean_stock_1c1',
#  'trade_log_return_realized_volatility_200_mean_stock_2c1',
#  'trade_log_return_realized_volatility_200_mean_stock_3c1',
#  'trade_log_return_realized_volatility_200_mean_stock_4c1',
#  'trade_log_return_realized_volatility_200_mean_stock_5c1',
#  'trade_log_return_realized_volatility_200_mean_stock_6c1',
#  'trade_log_return_realized_volatility_200_std_stock_0c1',
#  'trade_log_return_realized_volatility_200_std_stock_1c1',
#  'trade_log_return_realized_volatility_200_std_stock_2c1',
#  'trade_log_return_realized_volatility_200_std_stock_3c1',
#  'trade_log_return_realized_volatility_200_std_stock_4c1',
#  'trade_log_return_realized_volatility_200_std_stock_5c1',
#  'trade_log_return_realized_volatility_200_std_stock_6c1',
#  'trade_log_return_realized_volatility_200_max_stock_0c1',
#  'trade_log_return_realized_volatility_200_max_stock_1c1',
#  'trade_log_return_realized_volatility_200_max_stock_2c1',
#  'trade_log_return_realized_volatility_200_max_stock_3c1',
#  'trade_log_return_realized_volatility_200_max_stock_4c1',
#  'trade_log_return_realized_volatility_200_max_stock_5c1',
#  'trade_log_return_realized_volatility_200_max_stock_6c1',
#  'trade_log_return_realized_volatility_200_min_stock_0c1',
#  'trade_log_return_realized_volatility_200_min_stock_1c1',
#  'trade_log_return_realized_volatility_200_min_stock_2c1',
#  'trade_log_return_realized_volatility_200_min_stock_3c1',
#  'trade_log_return_realized_volatility_200_min_stock_4c1',
#  'trade_log_return_realized_volatility_200_min_stock_5c1',
#  'trade_log_return_realized_volatility_200_min_stock_6c1',
#  'log_return1_realized_volatility_mean_time_0c1',
#  'log_return1_realized_volatility_mean_time_1c1',
#  'log_return1_realized_volatility_mean_time_2c1',
#  'log_return1_realized_volatility_mean_time_3c1',
#  'log_return1_realized_volatility_mean_time_4c1',
#  'log_return1_realized_volatility_mean_time_5c1',
#  'log_return1_realized_volatility_mean_time_6c1',
#  'log_return1_realized_volatility_std_time_0c1',
#  'log_return1_realized_volatility_std_time_1c1',
#  'log_return1_realized_volatility_std_time_2c1',
#  'log_return1_realized_volatility_std_time_3c1',
#  'log_return1_realized_volatility_std_time_4c1',
#  'log_return1_realized_volatility_std_time_5c1',
#  'log_return1_realized_volatility_std_time_6c1',
#  'log_return1_realized_volatility_max_time_0c1',
#  'log_return1_realized_volatility_max_time_1c1',
#  'log_return1_realized_volatility_max_time_2c1',
#  'log_return1_realized_volatility_max_time_3c1',
#  'log_return1_realized_volatility_max_time_4c1',
#  'log_return1_realized_volatility_max_time_5c1',
#  'log_return1_realized_volatility_max_time_6c1',
#  'log_return1_realized_volatility_min_time_0c1',
#  'log_return1_realized_volatility_min_time_1c1',
#  'log_return1_realized_volatility_min_time_2c1',
#  'log_return1_realized_volatility_min_time_3c1',
#  'log_return1_realized_volatility_min_time_4c1',
#  ...]

# %%
nnn = ['time_id',
     'log_return1_realized_volatility_0c1',
     'log_return1_realized_volatility_1c1',     
     'log_return1_realized_volatility_3c1',
     'log_return1_realized_volatility_4c1',     
     'log_return1_realized_volatility_6c1',
     'total_volume_sum_0c1',
     'total_volume_sum_1c1', 
     'total_volume_sum_3c1',
     'total_volume_sum_4c1', 
     'total_volume_sum_6c1',
     'trade_size_sum_0c1',
     'trade_size_sum_1c1', 
     'trade_size_sum_3c1',
     'trade_size_sum_4c1', 
     'trade_size_sum_6c1',
     'trade_order_count_sum_0c1',
     'trade_order_count_sum_1c1',
     'trade_order_count_sum_3c1',
     'trade_order_count_sum_4c1',
     'trade_order_count_sum_6c1',      
     'price_spread_sum_0c1',
     'price_spread_sum_1c1',
     'price_spread_sum_3c1',
     'price_spread_sum_4c1',
     'price_spread_sum_6c1',   
     'bid_spread_sum_0c1',
     'bid_spread_sum_1c1',
     'bid_spread_sum_3c1',
     'bid_spread_sum_4c1',
     'bid_spread_sum_6c1',       
     'ask_spread_sum_0c1',
     'ask_spread_sum_1c1',
     'ask_spread_sum_3c1',
     'ask_spread_sum_4c1',
     'ask_spread_sum_6c1',   
     'volume_imbalance_sum_0c1',
     'volume_imbalance_sum_1c1',
     'volume_imbalance_sum_3c1',
     'volume_imbalance_sum_4c1',
     'volume_imbalance_sum_6c1',       
     'bid_ask_spread_sum_0c1',
     'bid_ask_spread_sum_1c1',
     'bid_ask_spread_sum_3c1',
     'bid_ask_spread_sum_4c1',
     'bid_ask_spread_sum_6c1',
     'size_tau2_0c1',
     'size_tau2_1c1',
     'size_tau2_3c1',
     'size_tau2_4c1',
     'size_tau2_6c1'] 
train = pd.merge(train,mat1[nnn],how='left',on='time_id')
test = pd.merge(test,mat2[nnn],how='left',on='time_id')

# %%
import gc
del mat1,mat2
gc.collect()
# Out:
# 436

# %%
from sklearn.model_selection import KFold
import lightgbm as lgb

seed0=2021
params0 = {
    'objective': 'rmse',
    'boosting_type': 'gbdt',
    'max_depth': -1,
    'max_bin':100,
    'min_data_in_leaf':500,
    'learning_rate': 0.05,
    'subsample': 0.72,
    'subsample_freq': 4,
    'feature_fraction': 0.5,
    'lambda_l1': 0.5,
    'lambda_l2': 1.0,
    'categorical_column':[0],
    'seed':seed0,
    'feature_fraction_seed': seed0,
    'bagging_seed': seed0,
    'drop_seed': seed0,
    'data_random_seed': seed0,
    'n_jobs':-1,
    'verbose': -1}
seed1=42
params1 = {
        'learning_rate': 0.1,        
        'lambda_l1': 2,
        'lambda_l2': 7,
        'num_leaves': 800,
        'min_sum_hessian_in_leaf': 20,
        'feature_fraction': 0.8,
        'feature_fraction_bynode': 0.8,
        'bagging_fraction': 0.9,
        'bagging_freq': 42,
        'min_data_in_leaf': 700,
        'max_depth': 4,
        'categorical_column':[0],
        'seed': seed1,
        'feature_fraction_seed': seed1,
        'bagging_seed': seed1,
        'drop_seed': seed1,
        'data_random_seed': seed1,
        'objective': 'rmse',
        'boosting': 'gbdt',
        'verbosity': -1,
        'n_jobs':-1,
    }
seed2 = 29
params2 = {
        'learning_rate': 0.15,        
        'lambda_l1': 2.154360665259325,
        'lambda_l2': 6.711089761523827,
        'num_leaves': 2769,
        'min_sum_hessian_in_leaf': 20.44437160769411,
        'feature_fraction': 0.7921473067441019,
        'feature_fraction_bynode': 0.8083803860191322,
        'bagging_fraction': 0.9726755660563261,
        'bagging_freq': 42,
        'min_data_in_leaf': 1690,
        'max_depth': 4,
        'seed': seed2,
        'feature_fraction_seed': seed2,
        'bagging_seed': seed2,
        'drop_seed': seed2,
        'data_random_seed': seed2,
        'objective': 'rmse',
        'boosting': 'gbdt',
        'verbosity': -1,
        'n_jobs': -1,
    } 
# Function to early stop with root mean squared percentage error
def rmspe(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))

def feval_rmspe(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'RMSPE', rmspe(y_true, y_pred), False

def train_and_evaluate_lgb(train, test, params,boost=1000):
    # Hyperparammeters (just basic)
    
    evals_result = {}
    
    features = [col for col in train.columns if col not in {"time_id", "target", "row_id"}]
    y = train['target']
    # Create out of folds array
    oof_predictions = np.zeros(train.shape[0])
    # Create test array to store predictions
    test_predictions = np.zeros(test.shape[0])
    # Create a KFold object
    kfold = KFold(n_splits = 5, random_state = 2021, shuffle = True)
    # Iterate through each fold
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(train)):
        print(f'Training fold {fold + 1}')
        x_train, x_val = train.iloc[trn_ind], train.iloc[val_ind]
        y_train, y_val = y.iloc[trn_ind], y.iloc[val_ind]
        # Root mean squared percentage error weights
        train_weights = 1 / np.square(y_train)
        val_weights = 1 / np.square(y_val)
        train_dataset = lgb.Dataset(x_train[features], y_train, weight = train_weights)
        val_dataset = lgb.Dataset(x_val[features], y_val, weight = val_weights)
        model = lgb.train(params = params,
                          num_boost_round=boost,
                          train_set = train_dataset, 
                          valid_sets = [train_dataset, val_dataset], 
                          verbose_eval = 250,
                          early_stopping_rounds=50,
                          feval = feval_rmspe,
                          evals_result=evals_result)
        # Add predictions to the out of folds array
        oof_predictions[val_ind] = model.predict(x_val[features])
        # Predict the test set
        test_predictions += model.predict(test[features]) / 5
    rmspe_score = rmspe(y, oof_predictions)
    print(f'Our out of folds RMSPE is {rmspe_score}')
    #lgb.plot_importance(model,max_num_features=20)
    # Return test predictions
    return test_predictions,model,evals_result
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
# %%time
# Traing and evaluate
#predictions_lgb= train_and_evaluate_lgb(train, test,params0)
predictions_lgb2,model,evals_result= train_and_evaluate_lgb(train, test,params2,boost=10000)
# Out:
# Training fold 1
# Training until validation scores don't improve for 50 rounds
# [250]	training's rmse: 0.000429959	training's RMSPE: 0.198847	valid_1's rmse: 0.000442731	valid_1's RMSPE: 0.205491
# [500]	training's rmse: 0.000410972	training's RMSPE: 0.190066	valid_1's rmse: 0.000428395	valid_1's RMSPE: 0.198837
# [750]	training's rmse: 0.000399776	training's RMSPE: 0.184888	valid_1's rmse: 0.000421006	valid_1's RMSPE: 0.195407
# [1000]	training's rmse: 0.000391345	training's RMSPE: 0.180989	valid_1's rmse: 0.000415687	valid_1's RMSPE: 0.192938
# [1250]	training's rmse: 0.000385377	training's RMSPE: 0.178229	valid_1's rmse: 0.000413246	valid_1's RMSPE: 0.191805
# [1500]	training's rmse: 0.000380207	training's RMSPE: 0.175838	valid_1's rmse: 0.000411725	valid_1's RMSPE: 0.191099
# [1750]	training's rmse: 0.000375708	training's RMSPE: 0.173757	valid_1's rmse: 0.000410539	valid_1's RMSPE: 0.190549
# [2000]	training's rmse: 0.000371706	training's RMSPE: 0.171907	valid_1's rmse: 0.00040907	valid_1's RMSPE: 0.189867
# [2250]	training's rmse: 0.000367939	training's RMSPE: 0.170164	valid_1's rmse: 0.000408275	valid_1's RMSPE: 0.189498
# Early stopping, best iteration is:
# [2390]	training's rmse: 0.000365886	training's RMSPE: 0.169215	valid_1's rmse: 0.000407796	valid_1's RMSPE: 0.189276
# Training fold 2
# Training until validation scores don't improve for 50 rounds
# [250]	training's rmse: 0.000429451	training's RMSPE: 0.198959	valid_1's rmse: 0.000439167	valid_1's RMSPE: 0.202415
# [500]	training's rmse: 0.000410516	training's RMSPE: 0.190187	valid_1's rmse: 0.000425384	valid_1's RMSPE: 0.196062
# [750]	training's rmse: 0.000399264	training's RMSPE: 0.184974	valid_1's rmse: 0.000417883	valid_1's RMSPE: 0.192605
# [1000]	training's rmse: 0.000391108	training's RMSPE: 0.181196	valid_1's rmse: 0.000413183	valid_1's RMSPE: 0.190439
# [1250]	training's rmse: 0.000384878	training's RMSPE: 0.178309	valid_1's rmse: 0.000410648	valid_1's RMSPE: 0.189271
# [1500]	training's rmse: 0.000379562	training's RMSPE: 0.175846	valid_1's rmse: 0.000408853	valid_1's RMSPE: 0.188443
# [1750]	training's rmse: 0.000374796	training's RMSPE: 0.173638	valid_1's rmse: 0.000407388	valid_1's RMSPE: 0.187768
# [2000]	training's rmse: 0.000370722	training's RMSPE: 0.171751	valid_1's rmse: 0.000406327	valid_1's RMSPE: 0.187279
# [2250]	training's rmse: 0.000366908	training's RMSPE: 0.169984	valid_1's rmse: 0.000405519	valid_1's RMSPE: 0.186907
# [2500]	training's rmse: 0.000363409	training's RMSPE: 0.168363	valid_1's rmse: 0.000404881	valid_1's RMSPE: 0.186612
# Early stopping, best iteration is:
# [2569]	training's rmse: 0.000362567	training's RMSPE: 0.167973	valid_1's rmse: 0.00040484	valid_1's RMSPE: 0.186594
# Training fold 3
# Training until validation scores don't improve for 50 rounds
# [250]	training's rmse: 0.000429422	training's RMSPE: 0.198592	valid_1's rmse: 0.000458259	valid_1's RMSPE: 0.212727
# [500]	training's rmse: 0.00041015	training's RMSPE: 0.189679	valid_1's rmse: 0.000443487	valid_1's RMSPE: 0.20587
# [750]	training's rmse: 0.000398575	training's RMSPE: 0.184326	valid_1's rmse: 0.000436468	valid_1's RMSPE: 0.202612
# Early stopping, best iteration is:
# [873]	training's rmse: 0.000394474	training's RMSPE: 0.18243	valid_1's rmse: 0.000433989	valid_1's RMSPE: 0.201461
# Training fold 4
# Training until validation scores don't improve for 50 rounds
# [250]	training's rmse: 0.000429887	training's RMSPE: 0.199162	valid_1's rmse: 0.000445305	valid_1's RMSPE: 0.205243
# [500]	training's rmse: 0.000409735	training's RMSPE: 0.189826	valid_1's rmse: 0.000429399	valid_1's RMSPE: 0.197911
# [750]	training's rmse: 0.000398858	training's RMSPE: 0.184787	valid_1's rmse: 0.000422279	valid_1's RMSPE: 0.19463
# [1000]	training's rmse: 0.000390907	training's RMSPE: 0.181103	valid_1's rmse: 0.000417896	valid_1's RMSPE: 0.19261
# [1250]	training's rmse: 0.000384746	training's RMSPE: 0.178249	valid_1's rmse: 0.00041534	valid_1's RMSPE: 0.191432
# [1500]	training's rmse: 0.000379594	training's RMSPE: 0.175862	valid_1's rmse: 0.000413288	valid_1's RMSPE: 0.190486
# [1750]	training's rmse: 0.000375177	training's RMSPE: 0.173815	valid_1's rmse: 0.000411775	valid_1's RMSPE: 0.189789
# [2000]	training's rmse: 0.000371139	training's RMSPE: 0.171944	valid_1's rmse: 0.000411072	valid_1's RMSPE: 0.189465
# Early stopping, best iteration is:
# [2067]	training's rmse: 0.000370134	training's RMSPE: 0.171479	valid_1's rmse: 0.000410751	valid_1's RMSPE: 0.189317
# Training fold 5
# Training until validation scores don't improve for 50 rounds
# [250]	training's rmse: 0.000430824	training's RMSPE: 0.199275	valid_1's rmse: 0.000443232	valid_1's RMSPE: 0.20561
# [500]	training's rmse: 0.000411856	training's RMSPE: 0.190501	valid_1's rmse: 0.000429317	valid_1's RMSPE: 0.199155
# [750]	training's rmse: 0.000400396	training's RMSPE: 0.185201	valid_1's rmse: 0.000421959	valid_1's RMSPE: 0.195742
# [1000]	training's rmse: 0.000392352	training's RMSPE: 0.18148	valid_1's rmse: 0.000418904	valid_1's RMSPE: 0.194325
# [1250]	training's rmse: 0.000386037	training's RMSPE: 0.178559	valid_1's rmse: 0.000417096	valid_1's RMSPE: 0.193486
# Early stopping, best iteration is:
# [1329]	training's rmse: 0.00038425	training's RMSPE: 0.177732	valid_1's rmse: 0.000416326	valid_1's RMSPE: 0.193129
# Our out of folds RMSPE is 0.19202533607256478
# CPU times: user 1h 21min 6s, sys: 9.6 s, total: 1h 21min 16s
# Wall time: 20min 53s

# %%
test['target'] = predictions_lgb2
test[['row_id', 'target']].to_csv('submission.csv',index = False)

# %%
import matplotlib.pyplot as plt
fig,ax =plt.subplots(figsize=(15,150))
lgb.plot_importance(model,ax=ax)
plt.show()

# %%
fig,ax =plt.subplots(figsize=(15,150))
lgb.plot_importance(model,ax=ax,importance_type="gain")
plt.show()

# %%
print('Plotting metrics recorded during training...')
ax = lgb.plot_metric(evals_result, metric='RMSPE')
plt.show()
# Out:
# Plotting metrics recorded during training...

# %%
print('Plotting metrics recorded during training...')
ax = lgb.plot_metric(evals_result, metric='rmse')
plt.show()
# Out:
# Plotting metrics recorded during training...

# %%
train.corr()
# Out:
#                stock_id   time_id    target  wap1_sum  wap1_std  wap2_sum  \
# stock_id       1.000000  0.000018 -0.021637  0.021751 -0.004037  0.021750
# time_id        0.000018  1.000000 -0.010331 -0.005131 -0.003829 -0.005131
# target        -0.021637 -0.010331  1.000000 -0.054740  0.698705 -0.054748
# wap1_sum       0.021751 -0.005131 -0.054740  1.000000  0.099949  1.000000
# wap1_std      -0.004037 -0.003829  0.698705  0.099949  1.000000  0.099943
# ...                 ...       ...       ...       ...       ...       ...
# size_tau2_0c1  0.000023  0.013966 -0.419668 -0.293457 -0.377841 -0.293453
# size_tau2_1c1  0.000021  0.015447 -0.460415 -0.308965 -0.402094 -0.308961
# size_tau2_3c1  0.000033  0.019845 -0.435092 -0.286857 -0.383227 -0.286853
# size_tau2_4c1  0.000024  0.013160 -0.512518 -0.314929 -0.451672 -0.314924
# size_tau2_6c1  0.000023  0.010841 -0.251266 -0.147782 -0.260432 -0.147779
#
#                wap2_std  wap3_sum  wap3_std  wap4_sum  ...  \
# stock_id      -0.006987  0.021747 -0.004033  0.021749  ...
# time_id       -0.003989 -0.005130 -0.003892 -0.005131  ...
# target         0.715277 -0.054720  0.699637 -0.054706  ...
# wap1_sum       0.077063  1.000000  0.104064  1.000000  ...
# wap1_std       0.995862  0.099966  0.994025  0.099978  ...
# ...                 ...       ...       ...       ...  ...
# size_tau2_0c1 -0.376099 -0.293462 -0.377955 -0.293469  ...
# size_tau2_1c1 -0.400842 -0.308971 -0.402200 -0.308977  ...
# size_tau2_3c1 -0.381865 -0.286861 -0.383537 -0.286868  ...
# size_tau2_4c1 -0.451444 -0.314935 -0.451866 -0.314943  ...
# size_tau2_6c1 -0.259620 -0.147787 -0.258836 -0.147792  ...
#
#                bid_ask_spread_sum_0c1  bid_ask_spread_sum_1c1  \
# stock_id                    -0.000049               -0.000049
# time_id                     -0.008738               -0.014344
# target                       0.697515                0.702830
# wap1_sum                     0.215672                0.212021
# wap1_std                     0.665288                0.657417
# ...                               ...                     ...
# size_tau2_0c1               -0.546972               -0.513100
# size_tau2_1c1               -0.581135               -0.563512
# size_tau2_3c1               -0.555218               -0.539723
# size_tau2_4c1               -0.653318               -0.633599
# size_tau2_6c1               -0.325267               -0.254760
#
#                bid_ask_spread_sum_3c1  bid_ask_spread_sum_4c1  \
# stock_id                    -0.000043               -0.000039
# time_id                     -0.013972               -0.010938
# target                       0.682557                0.682851
# wap1_sum                     0.220639                0.206199
# wap1_std                     0.649096                0.613526
# ...                               ...                     ...
# size_tau2_0c1               -0.530700               -0.459555
# size_tau2_1c1               -0.581417               -0.521531
# size_tau2_3c1               -0.573118               -0.498864
# size_tau2_4c1               -0.660251               -0.600049
# size_tau2_6c1               -0.276041               -0.202507
#
#                bid_ask_spread_sum_6c1  size_tau2_0c1  size_tau2_1c1  \
# stock_id                    -0.000017       0.000023       0.000021
# time_id                     -0.010661       0.013966       0.015447
# target                       0.580996      -0.419668      -0.460415
# wap1_sum                     0.162356      -0.293457      -0.308965
# wap1_std                     0.550453      -0.377841      -0.402094
# ...                               ...            ...            ...
# size_tau2_0c1               -0.417388       1.000000       0.917160
# size_tau2_1c1               -0.433916       0.917160       1.000000
# size_tau2_3c1               -0.444610       0.854662       0.885700
# size_tau2_4c1               -0.484628       0.861096       0.920806
# size_tau2_6c1               -0.321514       0.419625       0.448173
#
#                size_tau2_3c1  size_tau2_4c1  size_tau2_6c1
# stock_id            0.000033       0.000024       0.000023
# time_id             0.019845       0.013160       0.010841
# target             -0.435092      -0.512518      -0.251266
# wap1_sum           -0.286857      -0.314929      -0.147782
# wap1_std           -0.383227      -0.451672      -0.260432
# ...                      ...            ...            ...
# size_tau2_0c1       0.854662       0.861096       0.419625
# size_tau2_1c1       0.885700       0.920806       0.448173
# size_tau2_3c1       1.000000       0.856650       0.407150
# size_tau2_4c1       0.856650       1.000000       0.499142
# size_tau2_6c1       0.407150       0.499142       1.000000
#
# [249 rows x 249 columns]

# %%
corr = train.corr()

# %%
sns.set(rc = {'figure.figsize':(30,30)})
sns.heatmap(corr,center=0)
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
train.columns.tolist()
# Out:
# ['stock_id',
#  'time_id',
#  'target',
#  'row_id',
#  'wap1_sum',
#  'wap1_std',
#  'wap2_sum',
#  'wap2_std',
#  'wap3_sum',
#  'wap3_std',
#  'wap4_sum',
#  'wap4_std',
#  'log_return1_realized_volatility',
#  'log_return2_realized_volatility',
#  'log_return3_realized_volatility',
#  'log_return4_realized_volatility',
#  'wap_balance_sum',
#  'wap_balance_amax',
#  'price_spread_sum',
#  'price_spread_amax',
#  'price_spread2_sum',
#  'price_spread2_amax',
#  'bid_spread_sum',
#  'bid_spread_amax',
#  'ask_spread_sum',
#  'ask_spread_amax',
#  'total_volume_sum',
#  'total_volume_amax',
#  'volume_imbalance_sum',
#  'volume_imbalance_amax',
#  'bid_ask_spread_sum',
#  'bid_ask_spread_amax',
#  'bollinger_band_balance1_sum',
#  'bollinger_band_balance1_amax',
#  'log_return1_realized_volatility_500',
#  'log_return2_realized_volatility_500',
#  'log_return3_realized_volatility_500',
#  'log_return4_realized_volatility_500',
#  'log_return1_realized_volatility_400',
#  'log_return2_realized_volatility_400',
#  'log_return3_realized_volatility_400',
#  'log_return4_realized_volatility_400',
#  'log_return1_realized_volatility_300',
#  'log_return2_realized_volatility_300',
#  'log_return3_realized_volatility_300',
#  'log_return4_realized_volatility_300',
#  'log_return1_realized_volatility_200',
#  'log_return2_realized_volatility_200',
#  'log_return3_realized_volatility_200',
#  'log_return4_realized_volatility_200',
#  'log_return1_realized_volatility_100',
#  'log_return2_realized_volatility_100',
#  'log_return3_realized_volatility_100',
#  'log_return4_realized_volatility_100',
#  'trade_log_return_realized_volatility',
#  'trade_seconds_in_bucket_count_unique',
#  'trade_size_sum',
#  'trade_size_amax',
#  'trade_size_amin',
#  'trade_order_count_sum',
#  'trade_order_count_amax',
#  'trade_amount_sum',
#  'trade_amount_amax',
#  'trade_amount_amin',
#  'trade_tendency',
#  'trade_f_max',
#  'trade_f_min',
#  'trade_df_max',
#  'trade_df_min',
#  'trade_abs_diff',
#  'trade_energy',
#  'trade_iqr_p',
#  'trade_abs_diff_v',
#  'trade_energy_v',
#  'trade_iqr_p_v',
#  'trade_log_return_realized_volatility_500',
#  'trade_seconds_in_bucket_count_unique_500',
#  'trade_size_sum_500',
#  'trade_order_count_sum_500',
#  'trade_log_return_realized_volatility_400',
#  'trade_seconds_in_bucket_count_unique_400',
#  'trade_size_sum_400',
#  'trade_order_count_sum_400',
#  'trade_log_return_realized_volatility_300',
#  'trade_seconds_in_bucket_count_unique_300',
#  'trade_size_sum_300',
#  'trade_order_count_sum_300',
#  'trade_log_return_realized_volatility_200',
#  'trade_seconds_in_bucket_count_unique_200',
#  'trade_size_sum_200',
#  'trade_order_count_sum_200',
#  'trade_log_return_realized_volatility_100',
#  'trade_seconds_in_bucket_count_unique_100',
#  'trade_size_sum_100',
#  'trade_order_count_sum_100',
#  'log_return1_realized_volatility_mean_stock',
#  'log_return1_realized_volatility_std_stock',
#  'log_return1_realized_volatility_max_stock',
#  'log_return1_realized_volatility_min_stock',
#  'log_return2_realized_volatility_mean_stock',
#  'log_return2_realized_volatility_std_stock',
#  'log_return2_realized_volatility_max_stock',
#  'log_return2_realized_volatility_min_stock',
#  'log_return1_realized_volatility_400_mean_stock',
#  'log_return1_realized_volatility_400_std_stock',
#  'log_return1_realized_volatility_400_max_stock',
#  'log_return1_realized_volatility_400_min_stock',
#  'log_return2_realized_volatility_400_mean_stock',
#  'log_return2_realized_volatility_400_std_stock',
#  'log_return2_realized_volatility_400_max_stock',
#  'log_return2_realized_volatility_400_min_stock',
#  'log_return1_realized_volatility_300_mean_stock',
#  'log_return1_realized_volatility_300_std_stock',
#  'log_return1_realized_volatility_300_max_stock',
#  'log_return1_realized_volatility_300_min_stock',
#  'log_return2_realized_volatility_300_mean_stock',
#  'log_return2_realized_volatility_300_std_stock',
#  'log_return2_realized_volatility_300_max_stock',
#  'log_return2_realized_volatility_300_min_stock',
#  'log_return1_realized_volatility_200_mean_stock',
#  'log_return1_realized_volatility_200_std_stock',
#  'log_return1_realized_volatility_200_max_stock',
#  'log_return1_realized_volatility_200_min_stock',
#  'log_return2_realized_volatility_200_mean_stock',
#  'log_return2_realized_volatility_200_std_stock',
#  'log_return2_realized_volatility_200_max_stock',
#  'log_return2_realized_volatility_200_min_stock',
#  'trade_log_return_realized_volatility_mean_stock',
#  'trade_log_return_realized_volatility_std_stock',
#  'trade_log_return_realized_volatility_max_stock',
#  'trade_log_return_realized_volatility_min_stock',
#  'trade_log_return_realized_volatility_400_mean_stock',
#  'trade_log_return_realized_volatility_400_std_stock',
#  'trade_log_return_realized_volatility_400_max_stock',
#  'trade_log_return_realized_volatility_400_min_stock',
#  'trade_log_return_realized_volatility_300_mean_stock',
#  'trade_log_return_realized_volatility_300_std_stock',
#  'trade_log_return_realized_volatility_300_max_stock',
#  'trade_log_return_realized_volatility_300_min_stock',
#  'trade_log_return_realized_volatility_200_mean_stock',
#  'trade_log_return_realized_volatility_200_std_stock',
#  'trade_log_return_realized_volatility_200_max_stock',
#  'trade_log_return_realized_volatility_200_min_stock',
#  'log_return1_realized_volatility_mean_time',
#  'log_return1_realized_volatility_std_time',
#  'log_return1_realized_volatility_max_time',
#  'log_return1_realized_volatility_min_time',
#  'log_return2_realized_volatility_mean_time',
#  'log_return2_realized_volatility_std_time',
#  'log_return2_realized_volatility_max_time',
#  'log_return2_realized_volatility_min_time',
#  'log_return1_realized_volatility_400_mean_time',
#  'log_return1_realized_volatility_400_std_time',
#  'log_return1_realized_volatility_400_max_time',
#  'log_return1_realized_volatility_400_min_time',
#  'log_return2_realized_volatility_400_mean_time',
#  'log_return2_realized_volatility_400_std_time',
#  'log_return2_realized_volatility_400_max_time',
#  'log_return2_realized_volatility_400_min_time',
#  'log_return1_realized_volatility_300_mean_time',
#  'log_return1_realized_volatility_300_std_time',
#  'log_return1_realized_volatility_300_max_time',
#  'log_return1_realized_volatility_300_min_time',
#  'log_return2_realized_volatility_300_mean_time',
#  'log_return2_realized_volatility_300_std_time',
#  'log_return2_realized_volatility_300_max_time',
#  'log_return2_realized_volatility_300_min_time',
#  'log_return1_realized_volatility_200_mean_time',
#  'log_return1_realized_volatility_200_std_time',
#  'log_return1_realized_volatility_200_max_time',
#  'log_return1_realized_volatility_200_min_time',
#  'log_return2_realized_volatility_200_mean_time',
#  'log_return2_realized_volatility_200_std_time',
#  'log_return2_realized_volatility_200_max_time',
#  'log_return2_realized_volatility_200_min_time',
#  'trade_log_return_realized_volatility_mean_time',
#  'trade_log_return_realized_volatility_std_time',
#  'trade_log_return_realized_volatility_max_time',
#  'trade_log_return_realized_volatility_min_time',
#  'trade_log_return_realized_volatility_400_mean_time',
#  'trade_log_return_realized_volatility_400_std_time',
#  'trade_log_return_realized_volatility_400_max_time',
#  'trade_log_return_realized_volatility_400_min_time',
#  'trade_log_return_realized_volatility_300_mean_time',
#  'trade_log_return_realized_volatility_300_std_time',
#  'trade_log_return_realized_volatility_300_max_time',
#  'trade_log_return_realized_volatility_300_min_time',
#  'trade_log_return_realized_volatility_200_mean_time',
#  'trade_log_return_realized_volatility_200_std_time',
#  'trade_log_return_realized_volatility_200_max_time',
#  'trade_log_return_realized_volatility_200_min_time',
#  'size_tau',
#  'size_tau_400',
#  'size_tau_300',
#  'size_tau_200',
#  'size_tau2',
#  'size_tau2_400',
#  'size_tau2_300',
#  'size_tau2_200',
#  'size_tau2_d',
#  'log_return1_realized_volatility_0c1',
#  'log_return1_realized_volatility_1c1',
#  'log_return1_realized_volatility_3c1',
#  'log_return1_realized_volatility_4c1',
#  'log_return1_realized_volatility_6c1',
#  'total_volume_sum_0c1',
#  'total_volume_sum_1c1',
#  'total_volume_sum_3c1',
#  'total_volume_sum_4c1',
#  'total_volume_sum_6c1',
#  'trade_size_sum_0c1',
#  'trade_size_sum_1c1',
#  'trade_size_sum_3c1',
#  'trade_size_sum_4c1',
#  'trade_size_sum_6c1',
#  'trade_order_count_sum_0c1',
#  'trade_order_count_sum_1c1',
#  'trade_order_count_sum_3c1',
#  'trade_order_count_sum_4c1',
#  'trade_order_count_sum_6c1',
#  'price_spread_sum_0c1',
#  'price_spread_sum_1c1',
#  'price_spread_sum_3c1',
#  'price_spread_sum_4c1',
#  'price_spread_sum_6c1',
#  'bid_spread_sum_0c1',
#  'bid_spread_sum_1c1',
#  'bid_spread_sum_3c1',
#  'bid_spread_sum_4c1',
#  'bid_spread_sum_6c1',
#  'ask_spread_sum_0c1',
#  'ask_spread_sum_1c1',
#  'ask_spread_sum_3c1',
#  'ask_spread_sum_4c1',
#  'ask_spread_sum_6c1',
#  'volume_imbalance_sum_0c1',
#  'volume_imbalance_sum_1c1',
#  'volume_imbalance_sum_3c1',
#  'volume_imbalance_sum_4c1',
#  'volume_imbalance_sum_6c1',
#  'bid_ask_spread_sum_0c1',
#  'bid_ask_spread_sum_1c1',
#  'bid_ask_spread_sum_3c1',
#  'bid_ask_spread_sum_4c1',
#  'bid_ask_spread_sum_6c1',
#  'size_tau2_0c1',
#  'size_tau2_1c1',
#  'size_tau2_3c1',
#  'size_tau2_4c1',
#  'size_tau2_6c1']

# %%
train
# Out:
#         stock_id  time_id    target     row_id    wap1_sum  wap1_std  \
# 0              0        5  0.004136        0-5  303.125061  0.000693
# 1              0       11  0.001445       0-11  200.047775  0.000262
# 2              0       16  0.002168       0-16  187.913849  0.000864
# 3              0       31  0.002195       0-31  119.859779  0.000757
# 4              0       62  0.001747       0-62  175.932861  0.000258
# ...          ...      ...       ...        ...         ...       ...
# 428927       126    32751  0.003461  126-32751  309.870453  0.000486
# 428928       126    32753  0.003113  126-32753  223.552139  0.001264
# 428929       126    32758  0.004070  126-32758  256.277039  0.000466
# 428930       126    32763  0.003357  126-32763  399.721741  0.000456
# 428931       126    32767  0.002090  126-32767  217.058914  0.000384
#
#           wap2_sum  wap2_std    wap3_sum  wap3_std  ...  \
# 0       303.105530  0.000781  303.134857  0.000637  ...
# 1       200.041168  0.000272  200.035614  0.000298  ...
# 2       187.939819  0.000862  187.923065  0.000670  ...
# 3       119.835945  0.000656  119.870163  0.000606  ...
# 4       175.934250  0.000317  175.928284  0.000215  ...
# ...            ...       ...         ...       ...  ...
# 428927  309.871368  0.000613  309.778625  0.000596  ...
# 428928  223.580322  0.001303  223.505493  0.001340  ...
# 428929  256.255066  0.000599  256.146057  0.000520  ...
# 428930  399.714325  0.000507  399.775391  0.000424  ...
# 428931  217.079727  0.000465  217.069031  0.000341  ...
#
#         bid_ask_spread_sum_0c1  bid_ask_spread_sum_1c1  \
# 0                     0.118397                0.113150
# 1                     0.072559                0.071506
# 2                     0.079010                0.091842
# 3                     0.072684                0.075466
# 4                     0.076716                0.073103
# ...                        ...                     ...
# 428927                0.088530                0.091100
# 428928                0.077133                0.072731
# 428929                0.070713                0.086828
# 428930                0.110701                0.127982
# 428931                0.075224                0.088471
#
#         bid_ask_spread_sum_3c1  bid_ask_spread_sum_4c1  \
# 0                     0.174687                0.155552
# 1                     0.122967                0.110758
# 2                     0.158230                0.142469
# 3                     0.133869                0.109418
# 4                     0.109770                0.110781
# ...                        ...                     ...
# 428927                0.148065                0.140075
# 428928                0.128888                0.121852
# 428929                0.148556                0.138048
# 428930                0.204786                0.185053
# 428931                0.149643                0.141470
#
#         bid_ask_spread_sum_6c1  size_tau2_0c1  size_tau2_1c1  size_tau2_3c1  \
# 0                     0.175661       0.058550       0.057267       0.078471
# 1                     0.099451       0.081235       0.078955       0.122289
# 2                     0.088431       0.078550       0.087378       0.116278
# 3                     0.139281       0.100382       0.089673       0.105948
# 4                     0.177286       0.087285       0.089068       0.112663
# ...                        ...            ...            ...            ...
# 428927                0.163514       0.064380       0.064007       0.089665
# 428928                0.100756       0.073644       0.065909       0.085298
# 428929                0.080120       0.098654       0.092117       0.124247
# 428930                0.194994       0.051648       0.054263       0.067649
# 428931                0.128776       0.077370       0.078584       0.108765
#
#         size_tau2_4c1  size_tau2_6c1
# 0            0.054691       0.050700
# 1            0.078616       0.045740
# 2            0.074977       0.080722
# 3            0.094684       0.055447
# 4            0.086381       0.046358
# ...               ...            ...
# 428927       0.061596       0.041157
# 428928       0.062453       0.062479
# 428929       0.090574       0.120507
# 428930       0.051358       0.040747
# 428931       0.079125       0.053870
#
# [428932 rows x 250 columns]

# %%
train_temp = train

# %%
explainer = shap.Explainer(model)

# %%
explainer.expected_value
# Out:
# array([0.00359997])

# %%
test_shap =test_shap.drop("row_id",axis=1)

# %%
shap_values = explainer.shap_values(X=test_shap)
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-51-6195a4b79be6> in <module>
# ----> 1 shap_values = explainer.shap_values(X=test_shap)
#
# /opt/conda/lib/python3.7/site-packages/shap/explainers/_tree.py in shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     343             elif self.model.model_type == "lightgbm":
#     344                 assert not approximate, "approximate=True is not supported for LightGBM models!"
# --> 345                 phi = self.model.original_model.predict(X, num_iteration=tree_limit, pred_contrib=True)
#     346                 # Note: the data must be joined on the last axis
#     347                 if self.model.original_model.params['objective'] == 'binary':
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    3142         return predictor.predict(data, start_iteration, num_iteration,
#    3143                                  raw_score, pred_leaf, pred_contrib,
# -> 3144                                  data_has_header, is_reshape)
#    3145
#    3146     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     726             preds, nrow = self.__pred_for_csc(data, start_iteration, num_iteration, predict_type)
#     727         elif isinstance(data, np.ndarray):
# --> 728             preds, nrow = self.__pred_for_np2d(data, start_iteration, num_iteration, predict_type)
#     729         elif isinstance(data, list):
#     730             try:
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in __pred_for_np2d(self, mat, start_iteration, num_iteration, predict_type)
#     817             return preds, nrow
#     818         else:
# --> 819             return inner_predict(mat, start_iteration, num_iteration, predict_type)
#     820
#     821     def __create_sparse_native(self, cs, out_shape, out_ptr_indptr, out_ptr_indices, out_ptr_data,
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in inner_predict(mat, start_iteration, num_iteration, predict_type, preds)
#     799                 c_str(self.pred_parameter),
#     800                 ctypes.byref(out_num_preds),
# --> 801                 preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#     802             if n_preds != out_num_preds.value:
#     803                 raise ValueError("Wrong length for predict results")
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in _safe_call(ret)
#     108     """
#     109     if ret != 0:
# --> 110         raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
#     111
#     112
#
# LightGBMError: The number of features in data (249) is not the same as it was in training data (247).
# You can set ``predict_disable_shape_check=true`` to discard this error, but please be aware what you are doing.

# %%
shap_values

# %%
shap.plots.waterfall(shap_values[0])

# %%
shap.plots.force(shap_values[0])

# %%
shap.plots.force(shap_values)

# %%
shap.plots.scatter(shap_values[:,"RM"], color=shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.bar(shap_values)
